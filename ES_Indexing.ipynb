# %%
import traceback
import elasticsearch
import time
from elasticsearch import Elasticsearch, helpers
import nltk
from nltk.corpus import stopwords
import re
import warnings
warnings.filterwarnings("ignore")

es = Elasticsearch()
es.info()
# Out:
# {'name': 'LAPTOP-7MB0IEVT',
#  'cluster_name': 'elasticsearch',
#  'cluster_uuid': 'oNpBH66-Rq-zeazU5rk3ew',
#  'version': {'number': '7.17.6',
#   'build_flavor': 'default',
#   'build_type': 'zip',
#   'build_hash': 'f65e9d338dc1d07b642e14a27f338990148ee5b6',
#   'build_date': '2022-08-23T11:08:48.893373482Z',
#   'build_snapshot': False,
#   'lucene_version': '8.11.1',
#   'minimum_wire_compatibility_version': '6.8.0',
#   'minimum_index_compatibility_version': '6.0.0-beta1'},
#  'tagline': 'You Know, for Search'}

# %%
FIELDS = ['abstract', 'instance']
INDEX_NAME = 'dbpedia1'
INDEX_SETTINGS = {
'settings': {
        'index': {
            'number_of_shards': 1,
            'number_of_replicas': 1,
            'similarity': {
                'default': {
                    'type': 'BM25'
                }
            }
        }
    },
    'mappings': {
            'properties': {
                'abstract': {
                    'type': 'text',
                    'term_vector': 'yes',
                    'analyzer': 'english'
                },
                'instance': {
                    'type': 'text',
                    'term_vector': 'yes',
                    'analyzer': 'english'
                }
            }
        }
    }

# %%
def generate_esindex():
    if es.indices.exists(INDEX_NAME):
        es.indices.delete(index=INDEX_NAME)    
    es.indices.create(index=INDEX_NAME, body=INDEX_SETTINGS)

generate_esindex()

# %%
def read_ttlfile(filename, size, enc='utf-8'):

    if size <= 0:
        print("size is larger")
        return

    with open(filename, encoding=enc) as f:
        for i,line in enumerate(f):
            if (size >= 0) and (i >= size+1):
                break
            if i == 0: 
                continue
            print(line.strip())

# %%
read_ttlfile("data/instance_types_en.ttl", 2)
# Out:
# <http://dbpedia.org/resource/Anarchism> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#Thing> .
# <http://dbpedia.org/resource/Achilles> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2002/07/owl#Thing> .

# %%
read_ttlfile("data/short_abstracts_en.ttl",2)
# Out:
# <http://dbpedia.org/resource/Animalia_(book)> <http://www.w3.org/2000/01/rdf-schema#comment> "Animalia is an illustrated children's book by Graeme Base. It was originally published in 1986, followed by a tenth anniversary edition in 1996, and a 25th anniversary edition in 2012. Over three million copies have been sold. A special numbered and signed anniversary edition was also published in 1996, with an embossed gold jacket."@en .
# <http://dbpedia.org/resource/Actrius> <http://www.w3.org/2000/01/rdf-schema#comment> "Actresses (Catalan: Actrius) is a 1997 Catalan language Spanish drama film produced and directed by Ventura Pons and based on the award-winning stage play E.R. by Josep Maria Benet i Jornet. The film has no male actors, with all roles played by females. The film was produced in 1996."@en .

# %%
stop_words = stopwords.words('english')
typesof_question=  ['what', 'why', 'where','who', 'which','when', 'whom', 'whose']
stop_words = [word for word in stop_words if word not in typesof_question]

# %%
def text_preprocessing(text):
    text = re.sub(' +', ' ', text)
    stop_words = stopwords.words('english')
    word_list = [word for word in text.split() if word not in stop_words]
    text = " ".join(word_list)
    return text


def abstracts_preprocessing(text):
    page_list = re.findall('<.*?>', text)

    try:
        abstract = re.findall('\".*?\"', text)[0]
        abstract = text_preprocessing(abstract)
        if len(abstract)>2:
            abstract=abstract[1:-1]
        entity= page_list[0].split('/')[-1] 
        entity= entity[:-1].replace('_', ' ')
    except:
        abstract = ''
        entity = ''

    return entity, abstract
   

def entity_type_preprocessing(text):
    page_list = re.findall('<.*?>', text)

    try: 
        entity = page_list[0].split('/')[-1][:-1].replace('_', ' ')
        entity_type = page_list[-1].split('/')[-1][:-1].replace('owl#', '').replace('_', ' ')
        if entity_type=='Thing':
            entity_type='owl:Thing'
        else:
            entity_type='dbo:'+entity_type
    except:
        entity = ''
        entity_type = ''

    return entity, entity_type


def categories_preprocessing(text):
    page_list = re.findall('<.*?>', text) 
    entity = page_list[0].split('/')[-1][:-1]
    category = page_list[-1].split('/')[-1][:-1]
    category = category.replace('Category:','').replace('_', '')
    return entity.replace('_', ' '), category

# %%
size = 1500

def parse_abstracts(data, return_keys=False):   

    with open(file="data\short_abstracts_en.ttl", encoding='utf-8') as file:
        for i,line in enumerate(file):
            if (size >= 0) and (i >= size+1):
                break
            if i == 0: 
                continue
            entity, abstract = abstracts_preprocessing(line)

            if len(abstract)>0 and len(entity)>0:
                data.update({
                        entity:{ 
                        "_id": entity,
                            "abstract": abstract,
                            "instance":''
                        }
                        })
    if return_keys:                    
        return list(data.keys())

def parse_entity_type(data):
    entity_list = []
    with open(file="data\instance_types_en.ttl", encoding='utf-8') as f:
        for i,line in enumerate(f):
            if (size >= 0) and (i >= size+1):
                break
            if i == 0: 
                continue
            entity, entity_type = entity_type_preprocessing(line)

            if len(entity_type)>0 and len(entity)>0:
                entity_list.append(entity)
                try:
                    previous_entity = data[entity]['instance']
                    data[entity]['instance']=entity_type 
                except:
                    pass

# %%
data = {}

print("parseabstracts\n:",parse_abstracts(data))
print("--")
print("parseentity\n:", parse_entity_type(data))
print("---")
# Out:
# parseabstracts
# : None
# --
# parseentity
# : None
# ---

# %%
print("data")
data
# Out:
# data
# {'Animalia (book)': {'_id': 'Animalia (book)',
#   'abstract': "Animalia illustrated children's book Graeme Base. It originally published 1986, followed tenth anniversary edition 1996, 25th anniversary edition 2012. Over three million copies sold. A special numbered signed anniversary edition also published 1996, embossed gold jacket.",
#   'instance': 'dbo:Book'},
#  'Actrius': {'_id': 'Actrius',
#   'abstract': 'Actresses (Catalan: Actrius) 1997 Catalan language Spanish drama film produced directed Ventura Pons based award-winning stage play E.R. Josep Maria Benet Jornet. The film male actors, roles played females. The film produced 1996.',
#   'instance': 'dbo:Film'},
#  'Alain Connes': {'_id': 'Alain Connes',
#   'abstract': 'Alain Connes (French: [alɛ̃ kɔn]; born 1 April 1947) French mathematician, currently Professor Collège de France, IHÉS, The Ohio State University Vanderbilt University. He Invited Professor Conservatoire national des arts et métiers (2000).',
#   'instance': 'dbo:Scientist'},
#  'An American in Paris': {'_id': 'An American in Paris',
#   'abstract': 'An American Paris jazz-influenced symphonic poem American composer George Gershwin, written 1928. Inspired time Gershwin spent Paris, evokes sights energy French capital 1920s one best-known compositions.',
#   'instance': 'owl:Thing'},
#  'Astronomer': {'_id': 'Astronomer',
#   'abstract': 'An astronomer scientist field astronomy concentrates studies specific question field outside scope Earth. They look stars, planets, moons, comets galaxies, well many celestial objects — either observational astronomy, analyzing data theoretical astronomy. Examples topics fields astronomers work include: planetary science, solar astronomy, origin evolution stars, formation galaxies. There also related distinct subjects like cosmology studies Universe whole.',
#   'instance': 'owl:Thing'},
#  'International Atomic Time': {'_id': 'International Atomic Time',
#   'abstract': "International Atomic Time (TAI, French name Temps Atomique International) high-precision atomic coordinate time standard based notional passage proper time Earth's geoid. It basis Coordinated Universal Time (UTC), used civil timekeeping Earth's surface, Terrestrial Time, used astronomical calculations. As 30 June 2015 another leap second added, TAI exactly 36 seconds ahead UTC. The 36 seconds results initial difference 10 seconds start 1972, plus 26 leap seconds UTC since 1972.",
#   'instance': ''},
#  'Agricultural science': {'_id': 'Agricultural science',
#   'abstract': 'Agricultural science broad multidisciplinary field biology encompasses parts exact, natural, economic social sciences used practice understanding agriculture. (Veterinary science, animal science, often excluded definition.)',
#   'instance': 'owl:Thing'},
#  'Allan Dwan': {'_id': 'Allan Dwan',
#   'abstract': 'Allan Dwan (3 April 1885 – 28 December 1981) pioneering Canadian-born American motion picture director, producer screenwriter.',
#   'instance': 'dbo:Person'},
#  'List of Atlas Shrugged characters': {'_id': 'List of Atlas Shrugged characters',
#   'abstract': "This list characters Ayn Rand's novel Atlas Shrugged.",
#   'instance': ''},
#  'Achilles': {'_id': 'Achilles',
#   'abstract': "In Greek mythology, Achilles (/əˈkɪliːz/; Ancient Greek: Ἀχιλλεύς, Akhilleus, pronounced [akʰilːéu̯s]) Greek hero Trojan War central character greatest warrior Homer's Iliad. His mother nymph Thetis, father, Peleus, king Myrmidons.",
#   'instance': 'owl:Thing'},
#  'A': {'_id': 'A',
#   'abstract': "A (named /ˈeɪ/, plural As, A's, as, a's aes) first letter first vowel ISO basic Latin alphabet. It similar Ancient Greek letter alpha, derives. The upper-case version consists two slanting sides triangle, crossed middle horizontal bar. The lower-case version written two forms: double-storey single-storey ɑ. The latter commonly used handwriting fonts based it, especially fonts intended read children, also found italic type.",
#   'instance': ''},
#  'Arraignment': {'_id': 'Arraignment',
#   'abstract': 'Arraignment formal reading criminal charging document presence defendant inform defendant charges defendant. In response arraignment, accused expected enter plea. Acceptable pleas vary among jurisdictions, generally include \\',
#   'instance': ''},
#  'Answer': {'_id': 'Answer',
#   'abstract': 'Generally, answer reply question. It solution, retaliation response it. In law, answer originally solemn assertion opposition someone something, thus generally counter-statement defense, reply question response, objection, correct solution problem. The famous Latin Responsa Prudentium (\\',
#   'instance': ''},
#  'Appellate court': {'_id': 'Appellate court',
#   'abstract': "An appellate court, commonly called appeals court, court appeals (American English), appeal court (British English), court second instance second instance court, court law empowered hear appeal trial court lower tribunal. In jurisdictions, court system divided least three levels: trial court, initially hears cases reviews evidence testimony determine facts case; least one intermediate appellate court; supreme court (or court last resort) primarily reviews decisions intermediate courts. A jurisdiction's supreme court jurisdiction's highest appellate court. Appellate courts nationwide operate varying rules.",
#   'instance': ''},
#  'Albedo': {'_id': 'Albedo',
#   'abstract': 'Albedo (/ælˈbiːdoʊ/) \\',
#   'instance': ''},
#  'Appellate procedure in the United States': {'_id': 'Appellate procedure in the United States',
#   'abstract': "United States appellate procedure involves rules regulations filing appeals state courts federal courts. The nature appeal vary greatly depending type case rules court jurisdiction case prosecuted. There many types standard review appeals, de novo abuse discretion. However, appeals begin party files petition review higher court purpose overturning lower court's decision.",
#   'instance': 'owl:Thing'},
#  'Altruism': {'_id': 'Altruism',
#   'abstract': 'Altruism selflessness principle practice concern welfare others. It traditional virtue many cultures core aspect various religious traditions secular worldviews, though concept \\',
#   'instance': 'owl:Thing'},
#  'Afroasiatic languages': {'_id': 'Afroasiatic languages',
#   'abstract': 'Afroasiatic (Afro-Asiatic), also known Afrasian traditionally Hamito-Semitic (Chamito-Semitic), large language family several hundred related languages dialects. It comprises 300 living languages dialects, according 2009 Ethnologue estimate. It includes languages spoken predominantly Middle East, North Africa, Horn Africa, parts Sahel. Other widely spoken Afroasiatic languages include:',
#   'instance': 'owl:Thing'},
#  'Arithmetic mean': {'_id': 'Arithmetic mean',
#   'abstract': 'In mathematics statistics, arithmetic mean (/ˌærɪθˈmɛtɪk ˈmiːn/), simply mean average context clear, sum collection numbers divided number numbers collection. The collection often set results experiment, set results survey. The term \\',
#   'instance': ''},
#  'Academy Award for Best Production Design': {'_id': 'Academy Award for Best Production Design',
#   'abstract': "The Academy Award Best Production Design recognizes achievement art direction film. The category's original name Best Art Direction, changed current name 2012 85th Academy Awards. This change resulted Art Director's branch Academy Motion Picture Arts Sciences (AMPAS) renamed Designer's branch. Since 1947, award shared set decorator(s). It awarded best interior design film.",
#   'instance': 'dbo:Award'},
#  'Austroasiatic languages': {'_id': 'Austroasiatic languages',
#   'abstract': 'The Austroasiatic languages, recent classifications synonymous Mon–Khmer, large language family continental Southeast Asia, also scattered throughout India, Bangladesh, Nepal southern border China. The name Austroasiatic comes Latin words \\',
#   'instance': 'owl:Thing'},
#  'Affirming the consequent': {'_id': 'Affirming the consequent',
#   'abstract': 'Affirming consequent, sometimes called converse error, fallacy converse confusion necessity sufficiency, formal fallacy inferring converse original statement. The corresponding argument general form: 1. \\n* If P, Q. 2. \\n* Q. 3. \\n* Therefore, P. An argument form invalid, i.e., conclusion false even statements 1 2 true. Since P never asserted sufficient condition Q, factors could account Q (while P false).',
#   'instance': ''},
#  'Assistive technology': {'_id': 'Assistive technology',
#   'abstract': 'Assistive technology umbrella term includes assistive, adaptive, rehabilitative devices people disabilities also includes process used selecting, locating, using them. Assistive technology promotes greater independence enabling people perform tasks formerly unable accomplish, great difficulty accomplishing, providing enhancements to, changing methods interacting with, technology needed accomplish tasks.',
#   'instance': 'owl:Thing'},
#  'Atomic number': {'_id': 'Atomic number',
#   'abstract': '(See also: List elements atomic number) In chemistry physics, atomic number chemical element (also known proton number) number protons found nucleus atom element, therefore identical charge number nucleus. It conventionally represented symbol Z. The atomic number uniquely identifies chemical element. In uncharged atom, atomic number also equal number electrons.',
#   'instance': 'owl:Thing'},
#  'American National Standards Institute': {'_id': 'American National Standards Institute',
#   'abstract': 'The American National Standards Institute (ANSI, /ˈænsi/ AN-see) private non-profit organization oversees development voluntary consensus standards products, services, processes, systems, personnel United States. The organization also coordinates U.S. standards international standards American products used worldwide.',
#   'instance': 'dbo:Organisation'},
#  'Acid': {'_id': 'Acid',
#   'abstract': '(This article acids chemistry. For drug, see Lysergic acid diethylamide. For uses, see Acid (disambiguation).)(\\',
#   'instance': 'owl:Thing'},
#  'A Modest Proposal': {'_id': 'A Modest Proposal',
#   'abstract': '(\\',
#   'instance': 'dbo:Book'},
#  'America the Beautiful': {'_id': 'America the Beautiful',
#   'abstract': '\\',
#   'instance': 'dbo:Song'},
#  'Animation': {'_id': 'Animation',
#   'abstract': 'Animation process making illusion motion change means rapid display sequence static images minimally differ other. The illusion—as motion pictures general—is thought rely phi phenomenon. Animators artists specialize creation animation.Animation recorded either analogue media, flip book, motion picture film, video tape, digital media, including formats animated GIF, Flash animation digital video. To display animation, digital camera, computer, projector used along new technologies produced.',
#   'instance': 'owl:Thing'},
#  'Adventure': {'_id': 'Adventure',
#   'abstract': 'An adventure exciting unusual experience. It may also bold, usually risky undertaking, uncertain outcome. Adventures may activities potential physical danger traveling, exploring, skydiving, mountain climbing, scuba diving, river rafting participating extreme sports. The term also broadly refers enterprise potentially fraught physical, financial psychological risk, business venture, major life undertakings.',
#   'instance': ''},
#  'Aldous Huxley': {'_id': 'Aldous Huxley',
#   'abstract': 'Aldous Leonard Huxley (/ˈɔːldəs ˈhʌksli/; 26 July 1894 – 22 November 1963) English writer, novelist, philosopher, prominent member Huxley family. He graduated Balliol College, Oxford, first English literature.',
#   'instance': 'dbo:Writer'},
#  'ASCII': {'_id': 'ASCII',
#   'abstract': 'ASCII (/ˈæski/ ASS-kee), abbreviated American Standard Code Information Interchange, character encoding standard (the Internet Assigned Numbers Authority (IANA) prefers name US-ASCII). ASCII codes represent text computers, telecommunications equipment, devices. Most modern character-encoding schemes based ASCII, although support many additional characters.',
#   'instance': 'owl:Thing'},
#  'Alchemy': {'_id': 'Alchemy',
#   'abstract': 'Alchemy philosophical protoscientific tradition practiced throughout Europe, Egypt Asia. It aimed purify, mature, perfect certain objects. Common aims chrysopoeia, transmutation \\',
#   'instance': 'owl:Thing'},
#  'Animal Farm': {'_id': 'Animal Farm',
#   'abstract': 'Animal Farm allegorical dystopian novella George Orwell, first published England 17 August 1945. According Orwell, book reflects events leading Russian Revolution 1917 Stalinist era Soviet Union. Orwell, democratic socialist, critic Joseph Stalin hostile Moscow-directed Stalinism, attitude critically shaped experiences Spanish Civil War. The Soviet Union, believed, become brutal dictatorship, built upon cult personality enforced reign terror. In letter Yvonne Davet, Orwell described Animal Farm satirical tale Stalin (\\',
#   'instance': 'dbo:Book'},
#  'Ambiguity': {'_id': 'Ambiguity',
#   'abstract': 'Ambiguity type uncertainty meaning several interpretations plausible. It thus attribute idea statement whose intended meaning cannot definitively resolved according rule process finite number steps. (The ambi- part name reflects idea \\',
#   'instance': ''},
#  'Demographics of Angola': {'_id': 'Demographics of Angola',
#   'abstract': 'This article demographic features population Angola, including population density, ethnicity, education level, health populace, economic status, religious affiliations aspects population.',
#   'instance': 'owl:Thing'},
#  'Politics of Angola': {'_id': 'Politics of Angola',
#   'abstract': 'Since adoption new constitution 2010, politics Angola takes place framework presidential republic, whereby President Angola head state head government, multi-party system. Executive power exercised government. Legislative power vested President, government parliament.',
#   'instance': ''},
#  'American Football Conference': {'_id': 'American Football Conference',
#   'abstract': 'The American Football Conference (AFC) one two conferences National Football League (NFL). This conference counterpart, National Football Conference (NFC), currently contain 16 teams each, making 32 teams NFL. Both conferences created part 1970 merger rival American Football League (AFL), ten former AFL teams three NFL teams forming AFC, remaining thirteen NFL clubs forming NFC. A series league expansions division realignments occurred since merger, thus making current total 16 clubs per conference.',
#   'instance': ''},
#  'Aristotle': {'_id': 'Aristotle',
#   'abstract': "Aristotle (/ˈærɪˌstɒtəl/; Greek: Ἀριστοτέλης Greek pronunciation: [aristotélɛːs], Aristotélēs; 384–322 BC) Greek philosopher scientist born city Stagira, Chalkidice, northern periphery Classical Greece. His father, Nicomachus, died Aristotle child, whereafter Proxenus Atarneus became guardian. At seventeen eighteen years age, joined Plato's Academy Athens remained age thirty-seven (c. 347 BC). His writings cover many subjects – including physics, biology, zoology, metaphysics, logic, ethics, aesthetics, poetry, theater, music, rhetoric, linguistics, politics government – constitute first comprehensive system Western philosophy. Shortly Plato died, Aristotle left Athens and, reques",
#   'instance': 'dbo:Philosopher'},
#  'Transport in Angola': {'_id': 'Transport in Angola',
#   'abstract': 'Transport Angola comprises:',
#   'instance': ''},
#  'Analysis of variance': {'_id': 'Analysis of variance',
#   'abstract': 'Analysis variance (ANOVA) collection statistical models used analyze differences among group means associated procedures (such \\',
#   'instance': 'owl:Thing'},
#  'Adobe': {'_id': 'Adobe',
#   'abstract': 'Adobe (US /əˈdoʊbi/, UK /əˈdoʊb/; Spanish: [aˈðoβe], ultimately Coptic via Arabic) building material made earth often organic material. Adobe means mudbrick Spanish, English speaking regions Spanish heritage refers kind earth construction, adobe buildings similar appearance cob rammed earth buildings. Adobe among earliest building materials, used throughout world.',
#   'instance': 'owl:Thing'},
#  'Abacus': {'_id': 'Abacus',
#   'abstract': 'The abacus (plural abaci abacuses), also called counting frame, calculating tool use Europe, China Russia, centuries adoption written Hindu–Arabic numeral system still used merchants, traders clerks parts Eastern Europe, Russia, China Africa. Today, abaci often constructed bamboo frame beads sliding wires, originally beans stones moved grooves sand tablets wood, stone, metal.',
#   'instance': 'owl:Thing'},
#  'Foreign relations of Angola': {'_id': 'Foreign relations of Angola',
#   'abstract': "The foreign relations Angola based Angola's strong support U.S. foreign policy Angolan economy dependent U.S. foreign aid. From 1975 1989, Angola aligned Eastern bloc, particular Soviet Union, Libya, Cuba. Since then, focused improving relationships Western countries, cultivating links Portuguese-speaking countries, asserting national interests Central Africa military diplomatic intervention. In 1993, established formal diplomatic relations United States. It entered Southern African Development Community vehicle improving ties largely Anglophone neighbors south. Zimbabwe Namibia joined Angola military intervention Democrati",
#   'instance': ''},
#  'Academy Awards': {'_id': 'Academy Awards',
#   'abstract': 'The Academy Awards, \\',
#   'instance': 'dbo:Award'},
#  'Asphalt': {'_id': 'Asphalt',
#   'abstract': 'Asphalt (US /ˈæsfɔːlt/, UK /ˈæsfælt/, occasionally /ˈæʃfɔːlt/), also known bitumen (US /bɪˈtjuːmən, baɪ-/, UK /ˈbɪtjᵿmən/) sticky, black highly viscous liquid semi-solid form petroleum. It may found natural deposits may refined product; substance classed pitch. Until 20th century, term asphaltum also used. The word derived Ancient Greek ἄσφαλτος ásphaltos.',
#   'instance': 'owl:Thing'},
#  'Andorra': {'_id': 'Andorra',
#   'abstract': "Andorra (/ænˈdɔːrə/; Catalan: [ənˈdorə], locally: [anˈdɔra]), officially Principality Andorra (Catalan: Principat d'Andorra), also called Principality Valleys Andorra (Catalan: Principat de les Valls d'Andorra), sovereign landlocked microstate Southwestern Europe, located eastern Pyrenees mountains bordered Spain France. Created charter 988, present principality formed 1278. It known principality monarchy headed two Co-Princes – Roman Catholic Bishop Urgell Spain, President France.",
#   'instance': 'dbo:Country'},
#  'Algorithms (journal)': {'_id': 'Algorithms (journal)',
#   'abstract': 'Algorithms peer-reviewed open access mathematics journal concerning design, analysis, experiments algorithms. The journal published MDPI established 2008 founding editor-in-chief Kazuo Iwama. Its current editor-in-chief Henning Fernau.',
#   'instance': 'dbo:AcademicJournal'},
#  'Abstract (law)': {'_id': 'Abstract (law)',
#   'abstract': 'In law, abstract brief statement contains important points long legal document several related legal papers.',
#   'instance': ''},
#  'Alphabet': {'_id': 'Alphabet',
#   'abstract': 'An alphabet standard set letters (basic written symbols graphemes) used write one languages based general principle letters represent phonemes (basic significant sounds) spoken language. This contrast types writing systems, syllabaries (in character represents syllable) logographies (in character represents word, morpheme, semantic unit).',
#   'instance': 'owl:Thing'},
#  'Android (robot)': {'_id': 'Android (robot)',
#   'abstract': 'An android humanoid robot synthetic organism designed look act like human, especially one body flesh-like resemblance. Historically, androids remained completely within domain science fiction frequently seen film television. Only recently advancements robot technology allowed design functional realistic humanoid robots.',
#   'instance': 'owl:Thing'},
#  'Anthropology': {'_id': 'Anthropology',
#   'abstract': 'Anthropology study various aspects humans within past present societies. Social anthropology cultural anthropology study norms values societies. Linguistic anthropology studies language affects social life. Biological physical anthropology studies biological development humans.',
#   'instance': 'owl:Thing'},
#  'Amateur astronomy': {'_id': 'Amateur astronomy',
#   'abstract': 'Amateur astronomy hobby whose participants enjoy watching sky, abundance objects found unaided eye, binoculars, telescopes. Even though scientific research main goal, many amateur astronomers make contribution astronomy monitoring variable stars, tracking asteroids discovering transient objects, comets novae.',
#   'instance': 'owl:Thing'},
#  'Astronaut': {'_id': 'Astronaut',
#   'abstract': 'An astronaut cosmonaut person trained human spaceflight program command, pilot, serve crew member spacecraft. Although generally reserved professional space travelers, terms sometimes applied anyone travels space, including scientists, politicians, journalists, tourists.',
#   'instance': 'owl:Thing'},
#  'Angolan Armed Forces': {'_id': 'Angolan Armed Forces',
#   'abstract': 'The Angolan Armed Forces (Portuguese: Forças Armadas Angolanas) FAA military Angola. The FAA include General Staff Armed Forces three components: Army (Exército), Navy (Marinha de Guerra) National Air Force (National Air Force). Reported total manpower 2013 107,000. The FAA headed Chief General Staff Geraldo Sachipengo Nunda since 2010, reports Minister National Defense, currently João Lourenço.',
#   'instance': 'dbo:MilitaryUnit'},
#  'Albert Sidney Johnston': {'_id': 'Albert Sidney Johnston',
#   'abstract': 'Albert Sidney Johnston (February 2, 1803 – April 6, 1862) served general three different armies: Texian (i.e., Republic Texas) Army, United States Army, Confederate States Army. He saw extensive combat military career, fighting actions Texas War Independence, Mexican–American War, Utah War, American Civil War. Johnston unrelated Confederate general Joseph E. Johnston.',
#   'instance': 'dbo:MilitaryPerson'},
#  'Andrei Tarkovsky': {'_id': 'Andrei Tarkovsky',
#   'abstract': 'Andrei Arsenyevich Tarkovsky (Russian: Андре́й Арсе́ньевич Тарко́вский; IPA: [ɐnˈdrʲej ɐrˈsʲenʲjɪvʲɪtɕ tɐrˈkofskʲɪj]; 4 April 1932 – 29 December 1986) Soviet Russian filmmaker, writer, film editor, film theorist, theatre opera director. Ingmar Bergman said Tarkovsky:\\',
#   'instance': 'dbo:Person'},
#  'Anarchism': {'_id': 'Anarchism',
#   'abstract': 'Anarchism political philosophy advocates self-governed societies based voluntary institutions. These often described stateless societies, although several authors defined specifically institutions based non-hierarchical free associations. Anarchism holds state undesirable, unnecessary, harmful. While anti-statism central, anarchism entails opposing authority hierarchical organisation conduct human relations, including, limited to, state system.',
#   'instance': 'owl:Thing'},
#  'Ampere': {'_id': 'Ampere',
#   'abstract': 'The ampere (SI unit symbol: A), often shortened \\',
#   'instance': ''},
#  'Ayn Rand': {'_id': 'Ayn Rand',
#   'abstract': "Ayn Rand (/ˈaɪn ˈrænd/; born Alisa Zinov'yevna Rosenbaum, Russian: Али́са Зино́вьевна Розенба́ум; February 2 [O.S. January 20] 1905 – March 6, 1982) Russian-American novelist, philosopher, playwright, screenwriter. She known two best-selling novels, The Fountainhead Atlas Shrugged, developing philosophical system called Objectivism. Educated Russia, moved United States 1926. She play produced Broadway 1935–1936. After two early novels initially unsuccessful America, achieved fame 1943 novel, The Fountainhead.",
#   'instance': 'dbo:Writer'},
#  'Annual plant': {'_id': 'Annual plant',
#   'abstract': 'An annual plant plant completes life cycle, germination production seed, within one year, dies. Summer annuals germinate spring early summer mature autumn year. Winter annuals germinate autumn mature spring summer following calendar year.',
#   'instance': 'owl:Thing'},
#  'Anatomy': {'_id': 'Anatomy',
#   'abstract': 'Anatomy branch biology concerned study structure organisms parts. Anatomy inherently tied embryology, comparative anatomy, evolutionary biology, phylogeny, processes anatomy generated immediate (embryology) long (evolution) timescales. Human anatomy one basic essential sciences medicine. Anatomy physiology, study (respectively) structure function organisms parts, make natural pair related disciplines, often studied together.',
#   'instance': 'owl:Thing'},
#  'Alkane': {'_id': 'Alkane',
#   'abstract': 'In organic chemistry, alkane, paraffin (a historical name also meanings), acyclic saturated hydrocarbon. In words, alkane consists hydrogen carbon atoms arranged tree structure carbon-carbon bonds single. Alkanes general chemical formula CnH2n+2. For example, case n = 1 CH4, methane. Alkanes reactive little biological activity. They viewed molecular trees upon hung active/reactive functional groups biological molecules.',
#   'instance': 'owl:Thing'},
#  'Agriculture': {'_id': 'Agriculture',
#   'abstract': 'Agriculture cultivation animals, plants fungi food, fiber, biofuel, medicinal plants products used sustain enhance human life. Agriculture key development rise sedentary human civilization, whereby farming domesticated species created food surpluses nurtured development civilization. The study agriculture known agricultural science. The history agriculture dates back thousands years, development driven defined greatly different climates, cultures, technologies. Industrial agriculture based large-scale monoculture farming become dominant agricultural methodology.',
#   'instance': 'owl:Thing'},
#  'Anthophyta': {'_id': 'Anthophyta',
#   'abstract': 'The anthophytes thought clade comprising plants bearing flower-like structures. The group contained angiosperms - extant flowering plants, roses grasses - well Gnetales extinct Bennettitales. Detailed morphological molecular studies shown group actually monophyletic, proposed floral homologies gnetophytes angiosperms evolved parallel. This makes easier reconcile molecular clock data suggests angiosperms diverged gymnosperms around 300 million years ago.',
#   'instance': ''},
#  'Articles of Confederation': {'_id': 'Articles of Confederation',
#   'abstract': 'The Articles Confederation, formally Articles Confederation Perpetual Union, agreement among thirteen original states United States America served first constitution. Its drafting committee appointed Second Continental Congress began July 12, 1776, approved version sent states ratification late 1777. The formal ratification thirteen states completed early 1781. Government Articles superseded new constitution federal form government 1789.',
#   'instance': 'owl:Thing'},
#  'Atlantic Ocean': {'_id': 'Atlantic Ocean',
#   'abstract': '(\\',
#   'instance': 'dbo:BodyOfWater'},
#  'Art': {'_id': 'Art',
#   'abstract': "Art diverse range human activities creating visual, auditory performing artifacts (artworks), expressing author's imaginative technical skill, intended appreciated beauty emotional power. In general form activities include production works art, criticism art, study history art, aesthetic dissemination art. The nature art, related concepts creativity interpretation, explored branch philosophy known aesthetics.",
#   'instance': 'owl:Thing'},
#  'Allah': {'_id': 'Allah',
#   'abstract': "Allah (/ˈælə, ˈɑːlə, əlˈlɑː/; Arabic: الله\u200e, translit. Allāh\u200e, pronounced [ɑɫ'ɫɑh] ) Arabic word referring God Abrahamic religions. The word thought derived contraction al-ilāh, means \\",
#   'instance': 'owl:Thing'},
#  'Allocution': {'_id': 'Allocution',
#   'abstract': "An allocution, allocutus, formal statement made court defendant found guilty prior sentenced. It part criminal procedure jurisdictions using common law. It allows defendant explain sentence lenient. In plea bargains, allocution may required defendant. The defendant explicitly admits specifically detail actions reasons exchange reduced sentence. In principle, removes doubt exact nature defendant's guilt matter.",
#   'instance': ''},
#  'Arthur Schopenhauer': {'_id': 'Arthur Schopenhauer',
#   'abstract': 'Arthur Schopenhauer (German: [ˈaɐ̯tʊɐ̯ ˈʃoːpm̩ˌhaʊ̯ɐ]; 22 February 1788 – 21 September 1860) German philosopher. He best known 1818 work The World Will Representation, characterizes phenomenal world product blind, insatiable, malignant . Proceeding transcendental idealism Immanuel Kant, Schopenhauer developed atheistic metaphysical ethical system described exemplary manifestation philosophical pessimism, rejecting contemporaneous post-Kantian philosophies German idealism. Schopenhauer among first thinkers Western philosophy share affirm significant tenets Eastern philosophy (e.g., asceticism, world-as-appearance), initially arrived similar conclusions ',
#   'instance': 'dbo:Philosopher'},
#  'Alfred Korzybski': {'_id': 'Alfred Korzybski',
#   'abstract': "Alfred Habdank Skarbek Korzybski ([kɔˈʐɨpski]; July 3, 1879 – March 1, 1950) Polish-American independent scholar developed field called general semantics, viewed distinct from, encompassing than, field semantics. He argued human knowledge world limited human nervous system languages humans developed, thus one direct access reality, given know filtered brain's responses reality. His best known dictum \\",
#   'instance': 'dbo:Scientist'},
#  'Agnostida': {'_id': 'Agnostida',
#   'abstract': 'Agnostida order arthropod first developed near end Early Cambrian period thrived Middle Cambrian. They present Lower Cambrian fossil record along trilobites Redlichiida, Corynexochida, Ptychopariida orders. The last agnostids went extinct Late Ordovician.',
#   'instance': ''},
#  'Affidavit': {'_id': 'Affidavit',
#   'abstract': "An affidavit (/ˌæfᵻˈdeɪvᵻt/ A-fə-DAY-vət) written sworn statement fact voluntarily made affiant deponent oath affirmation administered person authorized law. Such statement witnessed authenticity affiant's signature taker oaths, notary public commissioner oaths. The name Medieval Latin he/she declared upon oath. An affidavit type verified statement showing, words, contains verification, meaning oath penalty perjury, serves evidence veracity required court proceedings.It done help court, stamp paper.Affidavits may written first third person, depending drafted document. If",
#   'instance': ''},
#  'Algeria': {'_id': 'Algeria',
#   'abstract': "Algeria (Arabic: الجزائر\u200e\u200e al-Jazā'ir; Berber: Dzayer, ⴷⵣⴰⵢⴻⵔ; French: Algérie), officially People's Democratic Republic Algeria, sovereign state North Africa Mediterranean coast. Its capital populous city Algiers, located country's far north. With area 2,381,741 square kilometres (919,595 sq mi), Algeria tenth-largest country world, largest Africa. Algeria bordered northeast Tunisia, east Libya, west Morocco, southwest Western Saharan territory, Mauritania, Mali, southeast Niger, north Mediterranean Sea. The country semi-presidential republic consisting 48 provinces 1,541 communes (counties). Abdelaziz Bouteflika Presid",
#   'instance': 'dbo:Country'},
#  'Algorithm': {'_id': 'Algorithm',
#   'abstract': 'what algorithm: \\',
#   'instance': 'owl:Thing'},
#  'Aikido': {'_id': 'Aikido',
#   'abstract': 'Aikido (Japanese: 合気道 Hepburn: Aikidō) [a.i.ki.doː] modern Japanese martial art developed Morihei Ueshiba synthesis martial studies, philosophy, religious beliefs. Aikido often translated \\',
#   'instance': 'owl:Thing'},
#  'Economy of Angola': {'_id': 'Economy of Angola',
#   'abstract': 'The Economy Angola one fastest-growing world, reported annual average GDP growth 11.1 percent 2001 2010. It still recovering Angolan Civil War plagued country independence 1975 2002. Despite extensive oil gas resources, diamonds, hydroelectric potential, rich agricultural land, Angola remains poor, third population relies subsistence agriculture. Since 2002, 27-year civil war ended, nation worked repair improve ravaged infrastructure weakened political social institutions. High international oil prices rising oil production contributed strong economic growth since 1998, corruption public-sector mismanagement remain, particularly ',
#   'instance': 'owl:Thing'},
#  'Asteroids (video game)': {'_id': 'Asteroids (video game)',
#   'abstract': "Asteroids arcade space shooter released November 1979 Atari, Inc. designed Lyle Rains, Ed Logg, Dominic Walsh. The player controls spaceship asteroid field periodically traversed flying saucers. The object game shoot destroy asteroids saucers colliding either hit saucers' counter-fire. The game becomes harder number asteroids increases.",
#   'instance': 'dbo:VideoGame'},
#  'Aruba': {'_id': 'Aruba',
#   'abstract': 'Aruba (/əˈruːbə/ ə-ROO-bə; Dutch: [aːˈrubaː]) constituent country Kingdom Netherlands southern Caribbean Sea, located 1,600 kilometres (990 mi) west main part Lesser Antilles 29 kilometres (18 mi) north coast Venezuela. It measures 32 kilometres (20 mi) long northwestern southeastern end 10 kilometres (6 mi) across widest point. Together Bonaire Curaçao, Aruba forms group referred ABC islands. Collectively, Aruba Dutch islands Caribbean often called Dutch Caribbean.',
#   'instance': 'dbo:Country'},
#  'Apollo': {'_id': 'Apollo',
#   'abstract': 'Apollo (Attic, Ionic, Homeric Greek: Ἀπόλλων, Apollōn (GEN Ἀπόλλωνος); Doric: Ἀπέλλων, Apellōn; Arcadocypriot: Ἀπείλων, Apeilōn; Aeolic: Ἄπλουν, Aploun; Latin: Apollō) one important complex Olympian deities classical Greek Roman religion Greek Roman mythology. The ideal kouros (a beardless, athletic youth), Apollo variously recognized god music, truth prophecy, healing, sun light, plague, poetry, more. Apollo son Zeus Leto, twin sister, chaste huntress Artemis. Apollo known Greek-influenced Etruscan mythology Apulu.',
#   'instance': 'owl:Thing'},
#  'Apollo 8': {'_id': 'Apollo 8',
#   'abstract': "Apollo 8, second human spaceflight mission United States Apollo space program, launched December 21, 1968, became first manned spacecraft leave Earth orbit, reach Earth's Moon, orbit return safely Earth. The three-astronaut crew — Commander Frank Borman, Command Module Pilot James Lovell, Lunar Module Pilot William Anders — became first humans travel beyond low Earth orbit, first see Earth whole planet, first directly see far side Moon, first witness Earthrise. The 1968 mission, third flight Saturn V rocket rocket's first manned launch, also first human spaceflight launch Kennedy Space Center, Florida, located adjacent Cape Canaveral Air Force Station.",
#   'instance': 'dbo:ArtificialSatellite'},
#  'Autism': {'_id': 'Autism',
#   'abstract': "Autism neurodevelopmental disorder characterized impaired social interaction, verbal non-verbal communication, restricted repetitive behavior. Parents usually notice signs first two years child's life. These signs often develop gradually, though children autism reach developmental milestones normal pace regress. The diagnostic criteria require symptoms become apparent early childhood, typically age three.",
#   'instance': 'dbo:Disease'},
#  'Andre Agassi': {'_id': 'Andre Agassi',
#   'abstract': "Andre Kirk Agassi (/ˈɑːndreɪ ˈæɡəsi/; born April 29, 1970) American retired professional tennis player former World No. 1, one game's dominant players early 1990s mid-2000s. Generally considered critics fellow players one greatest tennis players time, Agassi called greatest service returner history game. Described BBC upon retirement \\",
#   'instance': 'dbo:TennisPlayer'},
#  'Asia': {'_id': 'Asia',
#   'abstract': "Asia (/ˈeɪʒə, ˈeɪʃə/) Earth's largest populous continent, located primarily eastern northern hemispheres sharing continental landmass Eurasia continent Europe. Asia covers area 44,579,000 square kilometers, 30% Earth's total land area 8.7% Earth's total surface area. The continent, long home majority human population, site many first civilizations. Asia notable overall large size population, also dense large settlements well vast barely populated regions within continent 4.4 billion people.",
#   'instance': 'dbo:Continent'},
#  'Alaska': {'_id': 'Alaska',
#   'abstract': "Alaska (/əˈlæskə/) U.S. state situated northwest extremity Americas. The Canadian administrative divisions British Columbia Yukon border state east; extreme western part Attu Island; maritime border Russia west across Bering Strait. To north Chukchi Beaufort seas–the southern parts Arctic Ocean. The Pacific Ocean lies south southwest. Alaska largest state United States area, 3rd least populous least densely populated 50 United States. Approximately half Alaska's residents (the total estimated 738,432 U.S. Census Bureau 2015) live within Anchorage metropolitan area. Alaska's economy dominated fishing, natural gas, o",
#   'instance': 'dbo:AdministrativeRegion'},
#  'Anaconda': {'_id': 'Anaconda',
#   'abstract': 'Anacondas group large snakes genus Eunectes. They large snakes found tropical South America. Four species currently recognized.',
#   'instance': 'dbo:Reptile'},
#  'Apiales': {'_id': 'Apiales',
#   'abstract': 'The Apiales order flowering plants. The families recognized APG III system. This typical newer classifications, though slight variation, particular Torriceliaceae may divided. Under definition, well-known members include carrots, celery, parsley, ivy.',
#   'instance': ''},
#  'Algae': {'_id': 'Algae',
#   'abstract': 'Algae (/ˈældʒi, ˈælɡi/; singular alga /ˈælɡə/) informal term large, diverse group photosynthetic organisms necessarily closely related, thus polyphyletic. Included organisms range unicellular genera, Chlorella diatoms, multicellular forms, giant kelp, large brown alga may grow 50 length. Most aquatic autotrophic lack many distinct cell tissue types, stomata, xylem, phloem, found land plants. The largest complex marine algae called seaweeds, complex freshwater forms Charophyta, division green algae includes, example, Spirogyra stoneworts.',
#   'instance': 'owl:Thing'},
#  'Alismatales': {'_id': 'Alismatales',
#   'abstract': 'The Alismatales (alismatids) order flowering plants including 4500 species. Plants assigned order mostly tropical aquatic. Some grow fresh water, marine habitats.',
#   'instance': ''},
#  'Alabama': {'_id': 'Alabama',
#   'abstract': "Alabama (/ˌæləˈbæmə/) state southeastern region United States. It bordered Tennessee north, Georgia east, Florida Gulf Mexico south, Mississippi west. Alabama 30th-most extensive 24th-most populous 50 United States. At 1,300 miles (2,100 km), Alabama one nation's longest navigable inland waterways.",
#   'instance': 'dbo:AdministrativeRegion'},
#  'Aardvark': {'_id': 'Aardvark',
#   'abstract': 'The aardvark (/ˈɑːrd.vɑːrk/ ARD-vark; Orycteropus afer) medium-sized, burrowing, nocturnal mammal native Africa. It living species order Tubulidentata, although prehistoric species genera Tubulidentata known. Unlike insectivores, long pig-like snout, used sniff food. It roams southern two-thirds African continent, avoiding areas mainly rocky. A nocturnal feeder, subsists ants termites, dig hills using sharp claws powerful legs. It also digs create burrows live rear young. It receives \\',
#   'instance': ''},
#  'Amphibian': {'_id': 'Amphibian',
#   'abstract': 'Amphibians ectothermic, tetrapod vertebrates class Amphibia. Modern amphibians Lissamphibia. They inhabit wide variety habitats, species living within terrestrial, fossorial, arboreal freshwater aquatic ecosystems. Thus amphibians typically start larvae living water, species developed behavioural adaptations bypass this. The young generally undergo metamorphosis larva gills adult air-breathing form lungs. Amphibians use skin secondary respiratory surface small terrestrial salamanders frogs lack lungs rely entirely skin. They superficially similar lizards but, along mammals birds, reptiles amniotes require water bodies breed. Wi',
#   'instance': 'owl:Thing'},
#  'Asterales': {'_id': 'Asterales',
#   'abstract': 'Asterales /æstəˈreɪliːz/ order dicotyledonous flowering plants includes large family Asteraceae (or Compositae) known composite flowers made florets, ten families related Asteraceae. The order cosmopolite (plants found throughout world including desert frigid zones), includes mostly herbaceous species, although small number trees (such giant Lobelia giant Senecio) shrubs also present.',
#   'instance': ''},
#  'Abraham Lincoln': {'_id': 'Abraham Lincoln',
#   'abstract': 'Abraham Lincoln (/ˈeɪbrəhæm ˈlɪŋkən/; February 12, 1809 – April 15, 1865) American politician lawyer served 16th President United States March 1861 assassination April 1865. Lincoln led United States Civil War—its bloodiest war greatest moral, constitutional, political crisis. In so, preserved Union, abolished slavery, strengthened federal government, modernized economy. Lincoln consistently ranked scholars public one three greatest U.S. presidents.',
#   'instance': 'dbo:OfficeHolder'},
#  'Apollo 11': {'_id': 'Apollo 11',
#   'abstract': "Apollo 11 first spaceflight landed humans Moon. Mission commander Neil Armstrong pilot Buzz Aldrin landed lunar module Eagle July 20, 1969, 20:18 UTC. Armstrong became first step onto lunar surface six hours later July 21 02:56:15 UTC; Aldrin joined 20 minutes later. They spent two quarter hours together outside spacecraft, collected 47.5 pounds (21.5 kg) lunar material return Earth. Michael Collins piloted command module Columbia alone lunar orbit Moon's surface. Armstrong Aldrin spent day lunar surface rendezvousing Columbia lunar orbit.",
#   'instance': 'dbo:ArtificialSatellite'},
#  'Aardwolf': {'_id': 'Aardwolf',
#   'abstract': 'The aardwolf (Proteles cristata) small, insectivorous mammal, native East Southern Africa. Its name means \\',
#   'instance': ''},
#  'Actinopterygii': {'_id': 'Actinopterygii',
#   'abstract': 'Actinopterygii /ˌæktᵻnˌɒptəˈrɪdʒi.aɪ/, ray-finned fishes, constitute class subclass bony fishes. The ray-finned fishes called possess lepidotrichia \\',
#   'instance': 'owl:Thing'},
#  'Museum of Work': {'_id': 'Museum of Work',
#   'abstract': 'The Museum Work, Arbetets museum, museum located Norrköping, Sweden. The museum found 20th century building The Iron Motala ström river central Norrköping.',
#   'instance': ''},
#  'American Revolutionary War': {'_id': 'American Revolutionary War',
#   'abstract': "The American Revolutionary War (1775–1783), also known American War Independence Revolutionary War United States, armed conflict Great Britain thirteen North American colonies, declared independent United States America. Early fighting took place primarily North American continent. France, eager revenge defeat Seven Years' War, signed alliance new nation 1778 proved decisive ultimate victory. The conflict gradually expanded world war Britain combating France, Spain, Netherlands. Fighting also broke India British East India Company French allied Kingdom Mysore.",
#   'instance': 'dbo:MilitaryConflict'},
#  'Austrian German': {'_id': 'Austrian German',
#   'abstract': 'Austrian German (German: Österreichisches Deutsch), Austrian Standard German, Standard Austrian German (German: Österreichisches Standarddeutsch) Austrian High German (German: Österreichisches Hochdeutsch), variety Standard German written spoken Austria North Italy. It highest sociolinguistic prestige locally, variation used media formal situations. In less formal situations, Austrians tend use forms closer identical Bavarian Alemannic dialects, traditionally spoken – rarely written – Austria.',
#   'instance': 'dbo:Language'},
#  'Axiom of choice': {'_id': 'Axiom of choice',
#   'abstract': 'In mathematics, axiom choice, AC, axiom set theory equivalent statement Cartesian product collection non-empty sets non-empty. It states every indexed family nonempty sets exists indexed family elements every . The axiom choice formulated 1904 Ernst Zermelo order formalize proof well-ordering theorem.',
#   'instance': 'owl:Thing'},
#  'Alberta': {'_id': 'Alberta',
#   'abstract': "Alberta (/ælˈbɜːrtə/) western province Canada. With estimated population 4,196,457 July 1, 2015, Canada's fourth-most populous province populous Canada's three prairie provinces. Its area 660,000 square kilometres (250,000 sq mi). Alberta neighbour Saskatchewan districts Northwest Territories established provinces September 1, 1905. The premier Rachel Notley since May 2015.",
#   'instance': 'owl:Thing'},
#  'Angola': {'_id': 'Angola',
#   'abstract': 'Angola /æŋˈɡoʊlə/, officially Republic Angola (Portuguese: República de Angola pronounced: [ɐ̃ˈɡɔlɐ]; Kikongo, Kimbundu Umbundu: Repubilika ya Ngola), country Southern Africa. It seventh-largest country Africa, bordered Namibia south, Democratic Republic Congo north east, Zambia east, Atlantic Ocean west. The exclave province Cabinda borders Republic Congo Democratic Republic Congo. The capital largest city Angola Luanda.',
#   'instance': 'dbo:Country'},
#  'Mouthwash': {'_id': 'Mouthwash',
#   'abstract': 'Mouthwash, mouth rinse, oral rinse mouth bath, liquid held mouth passively swilled around mouth contraction perioral muscles and/or movement head, may gargled, head tilted back liquid bubbled back mouth.',
#   'instance': 'owl:Thing'},
#  'Aquarius (constellation)': {'_id': 'Aquarius (constellation)',
#   'abstract': 'Aquarius constellation zodiac, situated Capricornus Pisces. Its name Latin \\',
#   'instance': 'dbo:Constellation'},
#  'A Clockwork Orange (novel)': {'_id': 'A Clockwork Orange (novel)',
#   'abstract': 'A Clockwork Orange dystopian novel Anthony Burgess published 1962. Set near future English society featuring subculture extreme youth violence, teenage protagonist, Alex, narrates violent exploits experiences state authorities intent reforming him. The book partially written Russian-influenced argot called \\',
#   'instance': 'dbo:Book'},
#  'Aries (constellation)': {'_id': 'Aries (constellation)',
#   'abstract': "Aries one constellations zodiac. It located northern celestial hemisphere Pisces west Taurus east. The name Aries Latin ram, symbol (Unicode ♈), representing ram's horns. It one 48 constellations described 2nd century astronomer Ptolemy, remains one 88 modern constellations. It mid-sized constellation, ranking 39th overall size, area 441 square degrees (1.1% celestial sphere).",
#   'instance': 'dbo:Constellation'},
#  'Anime': {'_id': 'Anime',
#   'abstract': 'Anime (Japanese: アニメ, [anime] ) Japanese hand-drawn computer animation. The word abbreviated pronunciation \\',
#   'instance': 'owl:Thing'},
#  'Altaic languages': {'_id': 'Altaic languages',
#   'abstract': 'Altaic (/ælˈteɪᵻk/) proposed language family central Eurasia, widely seen discredited. Various versions included Turkic, Mongolic, Tungusic, Koreanic, Japonic languages. These languages spoken wide arc stretching northeast Asia Central Asia Anatolia eastern Europe. The group named Altai Mountains, mountain range Central Asia.',
#   'instance': 'owl:Thing'},
#  'Aegean Sea': {'_id': 'Aegean Sea',
#   'abstract': 'The Aegean Sea (/ᵻˈdʒiːən/; Greek: Αιγαίο Πέλαγος [eˈʝeo ˈpelaɣos] ; Turkish: Ege Denizi Turkish pronunciation: [eɟe denizi]) elongated embayment Mediterranean Sea located Greek Anatolian peninsulas, i.e., mainlands Greece Turkey. In north, connected Marmara Sea Black Sea Dardanelles Bosphorus. The Aegean Islands within sea bound southern periphery, including Crete Rhodes.',
#   'instance': 'dbo:Sea'},
#  'Aircraft': {'_id': 'Aircraft',
#   'abstract': 'An aircraft machine able fly gaining support air. It counters force gravity using either static lift using dynamic lift airfoil, cases downward thrust jet engines. The human activity surrounds aircraft called aviation. Crewed aircraft flown onboard pilot, unmanned aerial vehicles may remotely controlled self-controlled onboard computers. Aircraft may classified different criteria, lift type, aircraft propulsion, usage others.',
#   'instance': 'owl:Thing'},
#  'Asteroid': {'_id': 'Asteroid',
#   'abstract': 'Asteroids minor planets, especially inner Solar System. The larger ones also called planetoids. These terms historically applied astronomical object orbiting Sun show disc planet observed characteristics active comet. As minor planets outer Solar System discovered found volatile-based surfaces resemble comets, often distinguished asteroids asteroid belt. In article, term \\',
#   'instance': 'owl:Thing'},
#  'Abortion': {'_id': 'Abortion',
# ...
#   'instance': 'dbo:Royalty'},
#  'Adrastea (moon)': {'_id': 'Adrastea (moon)',
#   'abstract': 'Adrastea (/ædrəˈstiːə/ ad-rə-STEE-ə; Greek: Αδράστεια), also known Jupiter XV, second distance, smallest four inner moons Jupiter. It discovered photographs taken Voyager 2 1979, making first natural satellite discovered images taken interplanetary spacecraft, rather telescope. It officially named mythological Adrasteia, foster mother Greek god Zeus—the equivalent Roman god Jupiter.',
#   'instance': 'dbo:Planet'},
#  'Arbitration in the United States': {'_id': 'Arbitration in the United States',
#   'abstract': 'Arbitration, context United States law, form alternative dispute resolution—specifically, legal alternative litigation whereby parties dispute agree submit respective positions (through agreement hearing) neutral third party (the arbitrator(s) arbiter(s)) resolution. In practice arbitration generally used substitute judicial systems, particularly judicial processes viewed slow, expensive biased. Arbitration also used communities lack formal law, substitute formal law.',
#   'instance': ''},
#  'Abated': {'_id': 'Abated',
#   'abstract': 'Abated, ancient technical term applied masonry metal work portions sunk beneath surface, inscriptions ground sunk round letters leave letters ornament relief.',
#   'instance': ''},
#  'Adversarial system': {'_id': 'Adversarial system',
#   'abstract': "The adversarial system adversary system legal system used common law countries two advocates represent parties' positions impartial person group people, usually jury judge, attempt determine truth case. It contrast inquisitorial system used civil law systems (i.e. deriving Roman law Napoleonic code) judge group judges investigates case. The adversarial system two-sided structure criminal trial courts operate pits prosecution defense.",
#   'instance': ''},
#  'Arthur Phillip': {'_id': 'Arthur Phillip',
#   'abstract': 'Admiral Arthur Phillip RN (11 October 1738 – 31 August 1814) Royal Navy officer, first Governor New South Wales led colonisation Australia founded British penal colony later became city Sydney, Australia. After much experience sea, Phillip sailed First Fleet Governor-designate proposed British penal colony New South Wales. In January 1788, selected location Port Jackson (encompassing Sydney Harbour).',
#   'instance': 'dbo:OfficeHolder'},
#  'Abatis': {'_id': 'Abatis',
#   'abstract': 'An abatis, abattis, abbattis field fortification consisting obstacle formed (in modern era) branches trees laid row, sharpened tops directed outwards, towards enemy. The trees usually interlaced tied wire. Abatis used alone combination wire entanglements obstacles.',
#   'instance': ''},
#  'Abba Mari': {'_id': 'Abba Mari',
#   'abstract': 'Abba Mari ben Moses ben Joseph, Provençal rabbi, born Lunel, near Montpellier, towards end 13th century. He also known Yarhi birthplace (Hebrew Yerah, i.e. moon, lune), took name Astruc, Don Astruc En Astruc Lunel. The descendant men learned rabbinic lore, Abba Mari devoted study theology philosophy, made acquainted writings Moses Maimonides Nachmanides well Talmud.',
#   'instance': ''},
#  'Accounting': {'_id': 'Accounting',
#   'abstract': 'Accounting accountancy measurement, processing communication financial information economic entities businesses corporations. The modern field established Italian mathematician Luca Pacioli 1494. Accounting, called \\',
#   'instance': 'owl:Thing'},
#  "Antoine Thomson d'Abbadie": {'_id': "Antoine Thomson d'Abbadie",
#   'abstract': "Antoine Thomson d'Abbadie d'Arrast (3 January 1810 – 19 March 1897) French explorer, geographer, ethnologist, linguist astronomer notable travels Ethiopia first half 19th century. He older brother Arnaud Michel d'Abbadie, traveled.",
#   'instance': 'dbo:Scientist'},
#  'Apache HTTP Server': {'_id': 'Apache HTTP Server',
#   'abstract': "The Apache HTTP Server, colloquially called Apache (/əˈpætʃiː/ ə-PA-chee), world's used web server software. Originally based NCSA HTTPd server, development Apache began early 1995 work NCSA code stalled. Apache played key role initial growth World Wide Web, quickly overtaking NCSA HTTPd dominant HTTP server, remained popular since April 1996. In 2009, became first web server software serve 100 million websites.",
#   'instance': 'dbo:Software'},
#  'Angus': {'_id': 'Angus',
#   'abstract': 'Angus (Scottish Gaelic: Aonghas) one 32 local government council areas Scotland, registration county lieutenancy area. The council area borders Aberdeenshire, Dundee City Perth Kinross. Main industries include agriculture fishing. Global pharmaceuticals company GSK significant presence Montrose north county.',
#   'instance': ''},
#  'Aedicula': {'_id': 'Aedicula',
#   'abstract': 'In ancient Roman religion, aedicula (plural aediculae) small shrine. The word aedicula diminutive Latin aedes, temple building. Many aediculae household shrines held small altars statues Lares Penates. The Lares Roman deities protecting house family household gods. The Penates originally patron gods (really genii) storeroom, later becoming household gods guarding entire house.',
#   'instance': ''},
#  'Abbas Mirza': {'_id': 'Abbas Mirza',
#   'abstract': "Abbas Mirza (Persian: عباس میرزا\u200e\u200e) (August 26, 1789 – October 25, 1833), Qajar crown prince Persia. He developed reputation military commander Russo-Persian War 1804-1813 Russo-Persian War 1826-1828 neighbouring Imperial Russia, well Ottoman-Persian War 1821-1823 Ottoman Empire. He furthermore noted early modernizer Persia's armed forces institutions, death father, Fath Ali Shah. Abbas intelligent prince, possessed literary taste, noteworthy account comparative simplicity life.",
#   'instance': 'dbo:Royalty'},
#  'Abano Terme': {'_id': 'Abano Terme',
#   'abstract': "Abano Terme (known Abano Bagni 1924) town comune province Padua, Veneto region, Italy, eastern slope Colli Euganei; 10 kilometres (6 mi) southwest rail Padua. Abano Terme's population 19,062 (2001) (in 1901 4,556). The town's hot springs mud baths main economic resource. The waters temperature 80 °C (176 °F)",
#   'instance': 'dbo:Settlement'},
#  'Aedesius': {'_id': 'Aedesius',
#   'abstract': 'Aedesius (Ancient Greek: Αἰδέσιος, died 355 AD) Neoplatonist philosopher mystic born noble Cappadocian family.',
#   'instance': ''},
#  'Aeacus': {'_id': 'Aeacus',
#   'abstract': 'Aeacus (/ˈiːəkəs/; also spelled Eacus; Greek: Αἰακός) mythological king island Aegina Saronic Gulf. He father Peleus, Telamon Phocus grandfather Achilles Telemonian Ajax.',
#   'instance': 'owl:Thing'},
#  'Aegadian Islands': {'_id': 'Aegadian Islands',
#   'abstract': 'The Aegadian Islands (Italian: Isole Egadi; Sicilian: Ìsuli Ègadi, Latin: Aegates Insulae, Greek: Aegatae Nisoi, Αιγάται Νήσοι, meaning islands goats) group five small mountainous islands Mediterranean Sea northwest coast Sicily, Italy, near cities Trapani Marsala, total area 37.45 square kilometres (14.46 sq mi). The overall population 1987 estimated 5,000. Winter frost unknown rainfall low. The main occupation islanders fishing, largest tuna fishery Sicily here.',
#   'instance': ''},
#  'André the Giant': {'_id': 'André the Giant',
#   'abstract': 'André René Roussimoff (May 19, 1946 – January 27, 1993), known André Giant, French professional wrestler actor.He famously feuded Hulk Hogan, culminating WrestleMania III, best-remembered film role Fezzik, giant The Princess Bride. His size result gigantism caused excess growth hormone, later resulted acromegaly. It also led called \\',
#   'instance': 'dbo:Wrestler'},
#  'George Abbot (bishop)': {'_id': 'George Abbot (bishop)',
#   'abstract': 'George Abbot (19 October 1562 – 5 August 1633) English divine Archbishop Canterbury 1611 1633. He also served fourth Chancellor Trinity College, Dublin, 1612 1633. The Chambers Biographical Dictionary describes \\',
#   'instance': 'dbo:ChristianBishop'},
#  'Adware': {'_id': 'Adware',
#   'abstract': 'Adware, advertising-supported software, software package automatically renders advertisements order generate revenue author. The advertisements may user interface software screen presented user installation process. The functions may designed analyze Internet sites user visits present advertising pertinent types goods services featured there. The term sometimes used refer software displays unwanted advertisements known .',
#   'instance': ''},
#  'Aeclanum': {'_id': 'Aeclanum',
#   'abstract': 'Aeclanum (also spelled Aeculanum, Italian: Eclano, Greek: Αικούλανον) ancient town Samnium, southern Italy, c. 25 km east-southeast Beneventum, Via Appia. It lies Passo di Mirabella, near modern Mirabella Eclano.',
#   'instance': ''},
#  'Agent Orange': {'_id': 'Agent Orange',
#   'abstract': 'Agent Orange—or Herbicide Orange (HO)—is one herbicides defoliants used U.S. military part herbicidal warfare program, Operation Ranch Hand, Vietnam War 1961 1971. It mixture equal parts two herbicides, 2,4,5-T 2,4-D. Following conclusion War Southeast Asia, contention Agent Orange topic subsided. Two primary threads controversy relate toxicity agent potential long-term health effects additional potential exposure locations outside war-zone.',
#   'instance': 'owl:Thing'},
#  'Aedui': {'_id': 'Aedui',
#   'abstract': "The Aedui, Haedui, Hedui (Ancient Greek: Αἰδούοι) Gallic people Gallia Lugdunensis, inhabited country Arar (Saône) Liger (Loire), today's France. Their territory thus included greater part modern departments Saône-et-Loire, Côte-d'Or Nièvre.",
#   'instance': 'owl:Thing'},
#  'Abbas II of Egypt': {'_id': 'Abbas II of Egypt',
#   'abstract': "Abbas II Hilmi Bey (also known ‘Abbās Ḥilmī Pasha) (Arabic: عباس حلمي باشا\u200e\u200e) (14 July 1874 – 19 December 1944) last Khedive (Ottoman viceroy) Egypt Sudan, ruling 8 January 1892 19 December 1914. In 1914, Turkey joined Central Powers World War I, nationalist Khedive removed British, ruling Egypt, favor pro-British uncle, Hussein Kamel, marking de jure end Egypt's four-century era province Ottoman Empire, begun 1517.",
#   'instance': 'dbo:Monarch'},
#  'Aegeus': {'_id': 'Aegeus',
#   'abstract': 'In Greek mythology, Aegeus (/ˈɛdʒˌjuːs/; Ancient Greek: Αἰγεύς) Aegeas (/ˈiːdʒiəs/; Αιγέας), archaic figure founding myth Athens. The \\',
#   'instance': 'owl:Thing'},
#  'Aegospotami': {'_id': 'Aegospotami',
#   'abstract': 'Aegospotami (Αἰγὸς Ποταμοί) Aegospotamos (i.e. Goat Streams) ancient Greek name small river issuing Hellespont (Modern Turkish Çanakkale Boğazı), northeast Sestos. At mouth scene decisive battle 405 BC Lysander destroyed Athenian fleet, ending Peloponnesian War. The ancient Greek township name, whose existence attested coins 5th 4th centuries, river located ancient Thrace Chersonese.',
#   'instance': ''},
#  'Aegisthus': {'_id': 'Aegisthus',
#   'abstract': "Aegisthus (/ᵻˈdʒɪsθəs/; Ancient Greek: Αἴγισθος; also transliterated Aigisthos) figure Greek mythology. He son Thyestes daughter, Pelopia. The product incestuous union motivated father's rivalry house Atreus throne Mycenae, Aegisthus murdered Atreus restore father power. Later, lost throne Atreus's son Agamemnon.",
#   'instance': ''},
#  'Aegis': {'_id': 'Aegis',
#   'abstract': 'The aegis aigis (Ancient Greek: Αἰγίς; English pronunciation: /ˈiːdʒɪs/), stated Iliad, carried Athena Zeus, nature uncertain. It interpreted animal skin shield, sometimes bearing head Gorgon. There may connection deity named Aex Aix, daughter Helios nurse Zeus alternatively mistress Zeus (Hyginus, Astronomica 2. 13). The aegis Athena referred several places Iliad. \\',
#   'instance': ''},
#  'Aelianus Tacticus': {'_id': 'Aelianus Tacticus',
#   'abstract': "Aelianus Tacticus (Greek: Αἰλιανός ὁ Τακτικός; fl. 2nd century AD), also known Aelian (/ˈiːliən/), Greek military writer lived Rome. Aelian's military treatise fifty-three chapters tactics Greeks, titled On tactical arrays Greeks (Περὶ Στρατηγικῶν Τάξεων Ἑλληνικῶν), dedicated Emperor Hadrian, though probably mistake Trajan, date 106 AD assigned it. It handbook Greek, i.e. Macedonian, drill tactics practiced Hellenistic successors Alexander Great. The author claims consulted best authorities, important lost treatise subject Polybius. Perhaps chief value Aelian's work lies critical account preceding works ar",
#   'instance': 'owl:Thing'},
#  'Aegean civilizations': {'_id': 'Aegean civilizations',
#   'abstract': 'Aegean civilization general term European Bronze Age civilizations Greece around Aegean Sea. There three distinct communicating interacting geographic regions covered term: Crete, Cyclades Greek mainland. Crete associated Minoan civilization Early Bronze Age. The Cyclades converge mainland Early Helladic (\\',
#   'instance': 'owl:Thing'},
#  'Agarose': {'_id': 'Agarose',
#   'abstract': "An agarose polysaccharide polymer material, generally extracted seaweed. Agarose linear polymer made repeating unit agarobiose, disaccharide made D-galactose 3,6-anhydro-L-galactopyranose. Agarose one two principal components agar, purified agar removing agar's component, agaropectin.",
#   'instance': ''},
#  'Ajaigarh': {'_id': 'Ajaigarh',
#   'abstract': 'Ajaigarh Adjygurh (Hindi: अजैगढ) town nagar panchayat Panna District Madhya Pradesh state central India.',
#   'instance': ''},
#  'Abatement of debts and legacies': {'_id': 'Abatement of debts and legacies',
#   'abstract': 'Abatement debts legacies common law doctrine wills holds equitable assets deceased person sufficient satisfy fully creditors, debts must abate proportionately, must accept dividend. In case legacies funds assets payable sufficient pay full, legacies abate proportion, unless priority given specially particular legacy. Annuities also subject rule general legacies. The order abatement usually:',
#   'instance': ''},
#  'Afghan Turkestan': {'_id': 'Afghan Turkestan',
#   'abstract': 'Afghan Turkestan region northern Afghanistan, border former Soviet republics Turkmenistan, Uzbekistan Tajikistan. In 19th century province Afghanistan named Turkestan Province abolished Abdur Rahman, centred Mazari Sharif included territory modern provinces Balkh, Jowzjan, Faryab Sar-e Pol. The whole territory, junction Kokcha river Amu Darya north-east province Herat south-west, 500 miles (800 km) length, average width Russian frontier Hindu Kush 114 miles (183 km). It thus comprised 57,000 square miles (150,000 km2) roughly two-ninths former Kingdom Afghanistan.',
#   'instance': ''},
#  'Ajmer-Merwara': {'_id': 'Ajmer-Merwara',
#   'abstract': 'Ajmer-Merwara, also known Ajmir Province Ajmer-Merwara-Kekri, former province British India historical Ajmer region. The territory ceded British Daulat Rao Sindhia treaty June 25, 1818. It Bengal Presidency 1936 became part North-Western Provinces comissionat el 1842. Finally 1 April 1871 became separate province Ajmer-Merwara-Kekri. It became part independent India 15 August 1947 British left India.',
#   'instance': 'dbo:AdministrativeRegion'},
#  'Aelia Capitolina': {'_id': 'Aelia Capitolina',
#   'abstract': "Aelia Capitolina (/ˈiːliə ˌkæpᵻtəˈlaɪnə/; Latin full: COLONIA AELIA CAPITOLINA) Roman colony, built emperor Hadrian site Jerusalem, ruins since siege 70 AD, leading part Bar Kokhba revolt 132–136 AD. Aelia Capitolina remained official name Jerusalem 638 AD Arabs conquered city kept first part 'إلياء' (Iliyā').",
#   'instance': 'owl:Thing'},
#  'Affray': {'_id': 'Affray',
#   'abstract': "In many legal jurisdictions related English common law, affray public order offence consisting fighting one persons public place terror (in French: à l'effroi) ordinary people. Depending actions, laws prevailing jurisdiction, engaged affray may also render liable prosecution assault, unlawful assembly, riot; so, one offences usually charged.",
#   'instance': ''},
#  'Affiliation (family law)': {'_id': 'Affiliation (family law)',
#   'abstract': 'In law, affiliation (from Latin ad-filiare, adopt son) perviously term describe legal establishment paternity. The following description, part, written early 20th century, understood historical document.',
#   'instance': ''},
#  ...}

# %%
#removing no entity types
def entity_typeremoval(data):

    print("data before remove: ", len(data))
    items = []
    for k,v in data.items():
        if len(data[k]["instance"])==0:
            items.append(k)
    for i in items:
        data.pop(i)
    print("data after remove: ", len(data))

# %%
entity_typeremoval(data)
# Out:
# data before remove:  1500
# data after remove:  943

# %%
list(data.values())
# Out:
# [{'_id': 'Animalia (book)',
#   'abstract': "Animalia illustrated children's book Graeme Base. It originally published 1986, followed tenth anniversary edition 1996, 25th anniversary edition 2012. Over three million copies sold. A special numbered signed anniversary edition also published 1996, embossed gold jacket.",
#   'instance': 'dbo:Book'},
#  {'_id': 'Actrius',
#   'abstract': 'Actresses (Catalan: Actrius) 1997 Catalan language Spanish drama film produced directed Ventura Pons based award-winning stage play E.R. Josep Maria Benet Jornet. The film male actors, roles played females. The film produced 1996.',
#   'instance': 'dbo:Film'},
#  {'_id': 'Alain Connes',
#   'abstract': 'Alain Connes (French: [alɛ̃ kɔn]; born 1 April 1947) French mathematician, currently Professor Collège de France, IHÉS, The Ohio State University Vanderbilt University. He Invited Professor Conservatoire national des arts et métiers (2000).',
#   'instance': 'dbo:Scientist'},
#  {'_id': 'An American in Paris',
#   'abstract': 'An American Paris jazz-influenced symphonic poem American composer George Gershwin, written 1928. Inspired time Gershwin spent Paris, evokes sights energy French capital 1920s one best-known compositions.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Astronomer',
#   'abstract': 'An astronomer scientist field astronomy concentrates studies specific question field outside scope Earth. They look stars, planets, moons, comets galaxies, well many celestial objects — either observational astronomy, analyzing data theoretical astronomy. Examples topics fields astronomers work include: planetary science, solar astronomy, origin evolution stars, formation galaxies. There also related distinct subjects like cosmology studies Universe whole.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Agricultural science',
#   'abstract': 'Agricultural science broad multidisciplinary field biology encompasses parts exact, natural, economic social sciences used practice understanding agriculture. (Veterinary science, animal science, often excluded definition.)',
#   'instance': 'owl:Thing'},
#  {'_id': 'Allan Dwan',
#   'abstract': 'Allan Dwan (3 April 1885 – 28 December 1981) pioneering Canadian-born American motion picture director, producer screenwriter.',
#   'instance': 'dbo:Person'},
#  {'_id': 'Achilles',
#   'abstract': "In Greek mythology, Achilles (/əˈkɪliːz/; Ancient Greek: Ἀχιλλεύς, Akhilleus, pronounced [akʰilːéu̯s]) Greek hero Trojan War central character greatest warrior Homer's Iliad. His mother nymph Thetis, father, Peleus, king Myrmidons.",
#   'instance': 'owl:Thing'},
#  {'_id': 'Appellate procedure in the United States',
#   'abstract': "United States appellate procedure involves rules regulations filing appeals state courts federal courts. The nature appeal vary greatly depending type case rules court jurisdiction case prosecuted. There many types standard review appeals, de novo abuse discretion. However, appeals begin party files petition review higher court purpose overturning lower court's decision.",
#   'instance': 'owl:Thing'},
#  {'_id': 'Altruism',
#   'abstract': 'Altruism selflessness principle practice concern welfare others. It traditional virtue many cultures core aspect various religious traditions secular worldviews, though concept \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Afroasiatic languages',
#   'abstract': 'Afroasiatic (Afro-Asiatic), also known Afrasian traditionally Hamito-Semitic (Chamito-Semitic), large language family several hundred related languages dialects. It comprises 300 living languages dialects, according 2009 Ethnologue estimate. It includes languages spoken predominantly Middle East, North Africa, Horn Africa, parts Sahel. Other widely spoken Afroasiatic languages include:',
#   'instance': 'owl:Thing'},
#  {'_id': 'Academy Award for Best Production Design',
#   'abstract': "The Academy Award Best Production Design recognizes achievement art direction film. The category's original name Best Art Direction, changed current name 2012 85th Academy Awards. This change resulted Art Director's branch Academy Motion Picture Arts Sciences (AMPAS) renamed Designer's branch. Since 1947, award shared set decorator(s). It awarded best interior design film.",
#   'instance': 'dbo:Award'},
#  {'_id': 'Austroasiatic languages',
#   'abstract': 'The Austroasiatic languages, recent classifications synonymous Mon–Khmer, large language family continental Southeast Asia, also scattered throughout India, Bangladesh, Nepal southern border China. The name Austroasiatic comes Latin words \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Assistive technology',
#   'abstract': 'Assistive technology umbrella term includes assistive, adaptive, rehabilitative devices people disabilities also includes process used selecting, locating, using them. Assistive technology promotes greater independence enabling people perform tasks formerly unable accomplish, great difficulty accomplishing, providing enhancements to, changing methods interacting with, technology needed accomplish tasks.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Atomic number',
#   'abstract': '(See also: List elements atomic number) In chemistry physics, atomic number chemical element (also known proton number) number protons found nucleus atom element, therefore identical charge number nucleus. It conventionally represented symbol Z. The atomic number uniquely identifies chemical element. In uncharged atom, atomic number also equal number electrons.',
#   'instance': 'owl:Thing'},
#  {'_id': 'American National Standards Institute',
#   'abstract': 'The American National Standards Institute (ANSI, /ˈænsi/ AN-see) private non-profit organization oversees development voluntary consensus standards products, services, processes, systems, personnel United States. The organization also coordinates U.S. standards international standards American products used worldwide.',
#   'instance': 'dbo:Organisation'},
#  {'_id': 'Acid',
#   'abstract': '(This article acids chemistry. For drug, see Lysergic acid diethylamide. For uses, see Acid (disambiguation).)(\\',
#   'instance': 'owl:Thing'},
#  {'_id': 'A Modest Proposal', 'abstract': '(\\', 'instance': 'dbo:Book'},
#  {'_id': 'America the Beautiful', 'abstract': '\\', 'instance': 'dbo:Song'},
#  {'_id': 'Animation',
#   'abstract': 'Animation process making illusion motion change means rapid display sequence static images minimally differ other. The illusion—as motion pictures general—is thought rely phi phenomenon. Animators artists specialize creation animation.Animation recorded either analogue media, flip book, motion picture film, video tape, digital media, including formats animated GIF, Flash animation digital video. To display animation, digital camera, computer, projector used along new technologies produced.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Aldous Huxley',
#   'abstract': 'Aldous Leonard Huxley (/ˈɔːldəs ˈhʌksli/; 26 July 1894 – 22 November 1963) English writer, novelist, philosopher, prominent member Huxley family. He graduated Balliol College, Oxford, first English literature.',
#   'instance': 'dbo:Writer'},
#  {'_id': 'ASCII',
#   'abstract': 'ASCII (/ˈæski/ ASS-kee), abbreviated American Standard Code Information Interchange, character encoding standard (the Internet Assigned Numbers Authority (IANA) prefers name US-ASCII). ASCII codes represent text computers, telecommunications equipment, devices. Most modern character-encoding schemes based ASCII, although support many additional characters.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Alchemy',
#   'abstract': 'Alchemy philosophical protoscientific tradition practiced throughout Europe, Egypt Asia. It aimed purify, mature, perfect certain objects. Common aims chrysopoeia, transmutation \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Animal Farm',
#   'abstract': 'Animal Farm allegorical dystopian novella George Orwell, first published England 17 August 1945. According Orwell, book reflects events leading Russian Revolution 1917 Stalinist era Soviet Union. Orwell, democratic socialist, critic Joseph Stalin hostile Moscow-directed Stalinism, attitude critically shaped experiences Spanish Civil War. The Soviet Union, believed, become brutal dictatorship, built upon cult personality enforced reign terror. In letter Yvonne Davet, Orwell described Animal Farm satirical tale Stalin (\\',
#   'instance': 'dbo:Book'},
#  {'_id': 'Demographics of Angola',
#   'abstract': 'This article demographic features population Angola, including population density, ethnicity, education level, health populace, economic status, religious affiliations aspects population.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Aristotle',
#   'abstract': "Aristotle (/ˈærɪˌstɒtəl/; Greek: Ἀριστοτέλης Greek pronunciation: [aristotélɛːs], Aristotélēs; 384–322 BC) Greek philosopher scientist born city Stagira, Chalkidice, northern periphery Classical Greece. His father, Nicomachus, died Aristotle child, whereafter Proxenus Atarneus became guardian. At seventeen eighteen years age, joined Plato's Academy Athens remained age thirty-seven (c. 347 BC). His writings cover many subjects – including physics, biology, zoology, metaphysics, logic, ethics, aesthetics, poetry, theater, music, rhetoric, linguistics, politics government – constitute first comprehensive system Western philosophy. Shortly Plato died, Aristotle left Athens and, reques",
#   'instance': 'dbo:Philosopher'},
#  {'_id': 'Analysis of variance',
#   'abstract': 'Analysis variance (ANOVA) collection statistical models used analyze differences among group means associated procedures (such \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Adobe',
#   'abstract': 'Adobe (US /əˈdoʊbi/, UK /əˈdoʊb/; Spanish: [aˈðoβe], ultimately Coptic via Arabic) building material made earth often organic material. Adobe means mudbrick Spanish, English speaking regions Spanish heritage refers kind earth construction, adobe buildings similar appearance cob rammed earth buildings. Adobe among earliest building materials, used throughout world.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Abacus',
#   'abstract': 'The abacus (plural abaci abacuses), also called counting frame, calculating tool use Europe, China Russia, centuries adoption written Hindu–Arabic numeral system still used merchants, traders clerks parts Eastern Europe, Russia, China Africa. Today, abaci often constructed bamboo frame beads sliding wires, originally beans stones moved grooves sand tablets wood, stone, metal.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Academy Awards',
#   'abstract': 'The Academy Awards, \\',
#   'instance': 'dbo:Award'},
#  {'_id': 'Asphalt',
#   'abstract': 'Asphalt (US /ˈæsfɔːlt/, UK /ˈæsfælt/, occasionally /ˈæʃfɔːlt/), also known bitumen (US /bɪˈtjuːmən, baɪ-/, UK /ˈbɪtjᵿmən/) sticky, black highly viscous liquid semi-solid form petroleum. It may found natural deposits may refined product; substance classed pitch. Until 20th century, term asphaltum also used. The word derived Ancient Greek ἄσφαλτος ásphaltos.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Andorra',
#   'abstract': "Andorra (/ænˈdɔːrə/; Catalan: [ənˈdorə], locally: [anˈdɔra]), officially Principality Andorra (Catalan: Principat d'Andorra), also called Principality Valleys Andorra (Catalan: Principat de les Valls d'Andorra), sovereign landlocked microstate Southwestern Europe, located eastern Pyrenees mountains bordered Spain France. Created charter 988, present principality formed 1278. It known principality monarchy headed two Co-Princes – Roman Catholic Bishop Urgell Spain, President France.",
#   'instance': 'dbo:Country'},
#  {'_id': 'Algorithms (journal)',
#   'abstract': 'Algorithms peer-reviewed open access mathematics journal concerning design, analysis, experiments algorithms. The journal published MDPI established 2008 founding editor-in-chief Kazuo Iwama. Its current editor-in-chief Henning Fernau.',
#   'instance': 'dbo:AcademicJournal'},
#  {'_id': 'Alphabet',
#   'abstract': 'An alphabet standard set letters (basic written symbols graphemes) used write one languages based general principle letters represent phonemes (basic significant sounds) spoken language. This contrast types writing systems, syllabaries (in character represents syllable) logographies (in character represents word, morpheme, semantic unit).',
#   'instance': 'owl:Thing'},
#  {'_id': 'Android (robot)',
#   'abstract': 'An android humanoid robot synthetic organism designed look act like human, especially one body flesh-like resemblance. Historically, androids remained completely within domain science fiction frequently seen film television. Only recently advancements robot technology allowed design functional realistic humanoid robots.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Anthropology',
#   'abstract': 'Anthropology study various aspects humans within past present societies. Social anthropology cultural anthropology study norms values societies. Linguistic anthropology studies language affects social life. Biological physical anthropology studies biological development humans.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Amateur astronomy',
#   'abstract': 'Amateur astronomy hobby whose participants enjoy watching sky, abundance objects found unaided eye, binoculars, telescopes. Even though scientific research main goal, many amateur astronomers make contribution astronomy monitoring variable stars, tracking asteroids discovering transient objects, comets novae.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Astronaut',
#   'abstract': 'An astronaut cosmonaut person trained human spaceflight program command, pilot, serve crew member spacecraft. Although generally reserved professional space travelers, terms sometimes applied anyone travels space, including scientists, politicians, journalists, tourists.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Angolan Armed Forces',
#   'abstract': 'The Angolan Armed Forces (Portuguese: Forças Armadas Angolanas) FAA military Angola. The FAA include General Staff Armed Forces three components: Army (Exército), Navy (Marinha de Guerra) National Air Force (National Air Force). Reported total manpower 2013 107,000. The FAA headed Chief General Staff Geraldo Sachipengo Nunda since 2010, reports Minister National Defense, currently João Lourenço.',
#   'instance': 'dbo:MilitaryUnit'},
#  {'_id': 'Albert Sidney Johnston',
#   'abstract': 'Albert Sidney Johnston (February 2, 1803 – April 6, 1862) served general three different armies: Texian (i.e., Republic Texas) Army, United States Army, Confederate States Army. He saw extensive combat military career, fighting actions Texas War Independence, Mexican–American War, Utah War, American Civil War. Johnston unrelated Confederate general Joseph E. Johnston.',
#   'instance': 'dbo:MilitaryPerson'},
#  {'_id': 'Andrei Tarkovsky',
#   'abstract': 'Andrei Arsenyevich Tarkovsky (Russian: Андре́й Арсе́ньевич Тарко́вский; IPA: [ɐnˈdrʲej ɐrˈsʲenʲjɪvʲɪtɕ tɐrˈkofskʲɪj]; 4 April 1932 – 29 December 1986) Soviet Russian filmmaker, writer, film editor, film theorist, theatre opera director. Ingmar Bergman said Tarkovsky:\\',
#   'instance': 'dbo:Person'},
#  {'_id': 'Anarchism',
#   'abstract': 'Anarchism political philosophy advocates self-governed societies based voluntary institutions. These often described stateless societies, although several authors defined specifically institutions based non-hierarchical free associations. Anarchism holds state undesirable, unnecessary, harmful. While anti-statism central, anarchism entails opposing authority hierarchical organisation conduct human relations, including, limited to, state system.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Ayn Rand',
#   'abstract': "Ayn Rand (/ˈaɪn ˈrænd/; born Alisa Zinov'yevna Rosenbaum, Russian: Али́са Зино́вьевна Розенба́ум; February 2 [O.S. January 20] 1905 – March 6, 1982) Russian-American novelist, philosopher, playwright, screenwriter. She known two best-selling novels, The Fountainhead Atlas Shrugged, developing philosophical system called Objectivism. Educated Russia, moved United States 1926. She play produced Broadway 1935–1936. After two early novels initially unsuccessful America, achieved fame 1943 novel, The Fountainhead.",
#   'instance': 'dbo:Writer'},
#  {'_id': 'Annual plant',
#   'abstract': 'An annual plant plant completes life cycle, germination production seed, within one year, dies. Summer annuals germinate spring early summer mature autumn year. Winter annuals germinate autumn mature spring summer following calendar year.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Anatomy',
#   'abstract': 'Anatomy branch biology concerned study structure organisms parts. Anatomy inherently tied embryology, comparative anatomy, evolutionary biology, phylogeny, processes anatomy generated immediate (embryology) long (evolution) timescales. Human anatomy one basic essential sciences medicine. Anatomy physiology, study (respectively) structure function organisms parts, make natural pair related disciplines, often studied together.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Alkane',
#   'abstract': 'In organic chemistry, alkane, paraffin (a historical name also meanings), acyclic saturated hydrocarbon. In words, alkane consists hydrogen carbon atoms arranged tree structure carbon-carbon bonds single. Alkanes general chemical formula CnH2n+2. For example, case n = 1 CH4, methane. Alkanes reactive little biological activity. They viewed molecular trees upon hung active/reactive functional groups biological molecules.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Agriculture',
#   'abstract': 'Agriculture cultivation animals, plants fungi food, fiber, biofuel, medicinal plants products used sustain enhance human life. Agriculture key development rise sedentary human civilization, whereby farming domesticated species created food surpluses nurtured development civilization. The study agriculture known agricultural science. The history agriculture dates back thousands years, development driven defined greatly different climates, cultures, technologies. Industrial agriculture based large-scale monoculture farming become dominant agricultural methodology.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Articles of Confederation',
#   'abstract': 'The Articles Confederation, formally Articles Confederation Perpetual Union, agreement among thirteen original states United States America served first constitution. Its drafting committee appointed Second Continental Congress began July 12, 1776, approved version sent states ratification late 1777. The formal ratification thirteen states completed early 1781. Government Articles superseded new constitution federal form government 1789.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Atlantic Ocean', 'abstract': '(\\', 'instance': 'dbo:BodyOfWater'},
#  {'_id': 'Art',
#   'abstract': "Art diverse range human activities creating visual, auditory performing artifacts (artworks), expressing author's imaginative technical skill, intended appreciated beauty emotional power. In general form activities include production works art, criticism art, study history art, aesthetic dissemination art. The nature art, related concepts creativity interpretation, explored branch philosophy known aesthetics.",
#   'instance': 'owl:Thing'},
#  {'_id': 'Allah',
#   'abstract': "Allah (/ˈælə, ˈɑːlə, əlˈlɑː/; Arabic: الله\u200e, translit. Allāh\u200e, pronounced [ɑɫ'ɫɑh] ) Arabic word referring God Abrahamic religions. The word thought derived contraction al-ilāh, means \\",
#   'instance': 'owl:Thing'},
#  {'_id': 'Arthur Schopenhauer',
#   'abstract': 'Arthur Schopenhauer (German: [ˈaɐ̯tʊɐ̯ ˈʃoːpm̩ˌhaʊ̯ɐ]; 22 February 1788 – 21 September 1860) German philosopher. He best known 1818 work The World Will Representation, characterizes phenomenal world product blind, insatiable, malignant . Proceeding transcendental idealism Immanuel Kant, Schopenhauer developed atheistic metaphysical ethical system described exemplary manifestation philosophical pessimism, rejecting contemporaneous post-Kantian philosophies German idealism. Schopenhauer among first thinkers Western philosophy share affirm significant tenets Eastern philosophy (e.g., asceticism, world-as-appearance), initially arrived similar conclusions ',
#   'instance': 'dbo:Philosopher'},
#  {'_id': 'Alfred Korzybski',
#   'abstract': "Alfred Habdank Skarbek Korzybski ([kɔˈʐɨpski]; July 3, 1879 – March 1, 1950) Polish-American independent scholar developed field called general semantics, viewed distinct from, encompassing than, field semantics. He argued human knowledge world limited human nervous system languages humans developed, thus one direct access reality, given know filtered brain's responses reality. His best known dictum \\",
#   'instance': 'dbo:Scientist'},
#  {'_id': 'Algeria',
#   'abstract': "Algeria (Arabic: الجزائر\u200e\u200e al-Jazā'ir; Berber: Dzayer, ⴷⵣⴰⵢⴻⵔ; French: Algérie), officially People's Democratic Republic Algeria, sovereign state North Africa Mediterranean coast. Its capital populous city Algiers, located country's far north. With area 2,381,741 square kilometres (919,595 sq mi), Algeria tenth-largest country world, largest Africa. Algeria bordered northeast Tunisia, east Libya, west Morocco, southwest Western Saharan territory, Mauritania, Mali, southeast Niger, north Mediterranean Sea. The country semi-presidential republic consisting 48 provinces 1,541 communes (counties). Abdelaziz Bouteflika Presid",
#   'instance': 'dbo:Country'},
#  {'_id': 'Algorithm',
#   'abstract': 'what algorithm: \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Aikido',
#   'abstract': 'Aikido (Japanese: 合気道 Hepburn: Aikidō) [a.i.ki.doː] modern Japanese martial art developed Morihei Ueshiba synthesis martial studies, philosophy, religious beliefs. Aikido often translated \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Economy of Angola',
#   'abstract': 'The Economy Angola one fastest-growing world, reported annual average GDP growth 11.1 percent 2001 2010. It still recovering Angolan Civil War plagued country independence 1975 2002. Despite extensive oil gas resources, diamonds, hydroelectric potential, rich agricultural land, Angola remains poor, third population relies subsistence agriculture. Since 2002, 27-year civil war ended, nation worked repair improve ravaged infrastructure weakened political social institutions. High international oil prices rising oil production contributed strong economic growth since 1998, corruption public-sector mismanagement remain, particularly ',
#   'instance': 'owl:Thing'},
#  {'_id': 'Asteroids (video game)',
#   'abstract': "Asteroids arcade space shooter released November 1979 Atari, Inc. designed Lyle Rains, Ed Logg, Dominic Walsh. The player controls spaceship asteroid field periodically traversed flying saucers. The object game shoot destroy asteroids saucers colliding either hit saucers' counter-fire. The game becomes harder number asteroids increases.",
#   'instance': 'dbo:VideoGame'},
#  {'_id': 'Aruba',
#   'abstract': 'Aruba (/əˈruːbə/ ə-ROO-bə; Dutch: [aːˈrubaː]) constituent country Kingdom Netherlands southern Caribbean Sea, located 1,600 kilometres (990 mi) west main part Lesser Antilles 29 kilometres (18 mi) north coast Venezuela. It measures 32 kilometres (20 mi) long northwestern southeastern end 10 kilometres (6 mi) across widest point. Together Bonaire Curaçao, Aruba forms group referred ABC islands. Collectively, Aruba Dutch islands Caribbean often called Dutch Caribbean.',
#   'instance': 'dbo:Country'},
#  {'_id': 'Apollo',
#   'abstract': 'Apollo (Attic, Ionic, Homeric Greek: Ἀπόλλων, Apollōn (GEN Ἀπόλλωνος); Doric: Ἀπέλλων, Apellōn; Arcadocypriot: Ἀπείλων, Apeilōn; Aeolic: Ἄπλουν, Aploun; Latin: Apollō) one important complex Olympian deities classical Greek Roman religion Greek Roman mythology. The ideal kouros (a beardless, athletic youth), Apollo variously recognized god music, truth prophecy, healing, sun light, plague, poetry, more. Apollo son Zeus Leto, twin sister, chaste huntress Artemis. Apollo known Greek-influenced Etruscan mythology Apulu.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Apollo 8',
#   'abstract': "Apollo 8, second human spaceflight mission United States Apollo space program, launched December 21, 1968, became first manned spacecraft leave Earth orbit, reach Earth's Moon, orbit return safely Earth. The three-astronaut crew — Commander Frank Borman, Command Module Pilot James Lovell, Lunar Module Pilot William Anders — became first humans travel beyond low Earth orbit, first see Earth whole planet, first directly see far side Moon, first witness Earthrise. The 1968 mission, third flight Saturn V rocket rocket's first manned launch, also first human spaceflight launch Kennedy Space Center, Florida, located adjacent Cape Canaveral Air Force Station.",
#   'instance': 'dbo:ArtificialSatellite'},
#  {'_id': 'Autism',
#   'abstract': "Autism neurodevelopmental disorder characterized impaired social interaction, verbal non-verbal communication, restricted repetitive behavior. Parents usually notice signs first two years child's life. These signs often develop gradually, though children autism reach developmental milestones normal pace regress. The diagnostic criteria require symptoms become apparent early childhood, typically age three.",
#   'instance': 'dbo:Disease'},
#  {'_id': 'Andre Agassi',
#   'abstract': "Andre Kirk Agassi (/ˈɑːndreɪ ˈæɡəsi/; born April 29, 1970) American retired professional tennis player former World No. 1, one game's dominant players early 1990s mid-2000s. Generally considered critics fellow players one greatest tennis players time, Agassi called greatest service returner history game. Described BBC upon retirement \\",
#   'instance': 'dbo:TennisPlayer'},
#  {'_id': 'Asia',
#   'abstract': "Asia (/ˈeɪʒə, ˈeɪʃə/) Earth's largest populous continent, located primarily eastern northern hemispheres sharing continental landmass Eurasia continent Europe. Asia covers area 44,579,000 square kilometers, 30% Earth's total land area 8.7% Earth's total surface area. The continent, long home majority human population, site many first civilizations. Asia notable overall large size population, also dense large settlements well vast barely populated regions within continent 4.4 billion people.",
#   'instance': 'dbo:Continent'},
#  {'_id': 'Alaska',
#   'abstract': "Alaska (/əˈlæskə/) U.S. state situated northwest extremity Americas. The Canadian administrative divisions British Columbia Yukon border state east; extreme western part Attu Island; maritime border Russia west across Bering Strait. To north Chukchi Beaufort seas–the southern parts Arctic Ocean. The Pacific Ocean lies south southwest. Alaska largest state United States area, 3rd least populous least densely populated 50 United States. Approximately half Alaska's residents (the total estimated 738,432 U.S. Census Bureau 2015) live within Anchorage metropolitan area. Alaska's economy dominated fishing, natural gas, o",
#   'instance': 'dbo:AdministrativeRegion'},
#  {'_id': 'Anaconda',
#   'abstract': 'Anacondas group large snakes genus Eunectes. They large snakes found tropical South America. Four species currently recognized.',
#   'instance': 'dbo:Reptile'},
#  {'_id': 'Algae',
#   'abstract': 'Algae (/ˈældʒi, ˈælɡi/; singular alga /ˈælɡə/) informal term large, diverse group photosynthetic organisms necessarily closely related, thus polyphyletic. Included organisms range unicellular genera, Chlorella diatoms, multicellular forms, giant kelp, large brown alga may grow 50 length. Most aquatic autotrophic lack many distinct cell tissue types, stomata, xylem, phloem, found land plants. The largest complex marine algae called seaweeds, complex freshwater forms Charophyta, division green algae includes, example, Spirogyra stoneworts.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Alabama',
#   'abstract': "Alabama (/ˌæləˈbæmə/) state southeastern region United States. It bordered Tennessee north, Georgia east, Florida Gulf Mexico south, Mississippi west. Alabama 30th-most extensive 24th-most populous 50 United States. At 1,300 miles (2,100 km), Alabama one nation's longest navigable inland waterways.",
#   'instance': 'dbo:AdministrativeRegion'},
#  {'_id': 'Amphibian',
#   'abstract': 'Amphibians ectothermic, tetrapod vertebrates class Amphibia. Modern amphibians Lissamphibia. They inhabit wide variety habitats, species living within terrestrial, fossorial, arboreal freshwater aquatic ecosystems. Thus amphibians typically start larvae living water, species developed behavioural adaptations bypass this. The young generally undergo metamorphosis larva gills adult air-breathing form lungs. Amphibians use skin secondary respiratory surface small terrestrial salamanders frogs lack lungs rely entirely skin. They superficially similar lizards but, along mammals birds, reptiles amniotes require water bodies breed. Wi',
#   'instance': 'owl:Thing'},
#  {'_id': 'Abraham Lincoln',
#   'abstract': 'Abraham Lincoln (/ˈeɪbrəhæm ˈlɪŋkən/; February 12, 1809 – April 15, 1865) American politician lawyer served 16th President United States March 1861 assassination April 1865. Lincoln led United States Civil War—its bloodiest war greatest moral, constitutional, political crisis. In so, preserved Union, abolished slavery, strengthened federal government, modernized economy. Lincoln consistently ranked scholars public one three greatest U.S. presidents.',
#   'instance': 'dbo:OfficeHolder'},
#  {'_id': 'Apollo 11',
#   'abstract': "Apollo 11 first spaceflight landed humans Moon. Mission commander Neil Armstrong pilot Buzz Aldrin landed lunar module Eagle July 20, 1969, 20:18 UTC. Armstrong became first step onto lunar surface six hours later July 21 02:56:15 UTC; Aldrin joined 20 minutes later. They spent two quarter hours together outside spacecraft, collected 47.5 pounds (21.5 kg) lunar material return Earth. Michael Collins piloted command module Columbia alone lunar orbit Moon's surface. Armstrong Aldrin spent day lunar surface rendezvousing Columbia lunar orbit.",
#   'instance': 'dbo:ArtificialSatellite'},
#  {'_id': 'Actinopterygii',
#   'abstract': 'Actinopterygii /ˌæktᵻnˌɒptəˈrɪdʒi.aɪ/, ray-finned fishes, constitute class subclass bony fishes. The ray-finned fishes called possess lepidotrichia \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'American Revolutionary War',
#   'abstract': "The American Revolutionary War (1775–1783), also known American War Independence Revolutionary War United States, armed conflict Great Britain thirteen North American colonies, declared independent United States America. Early fighting took place primarily North American continent. France, eager revenge defeat Seven Years' War, signed alliance new nation 1778 proved decisive ultimate victory. The conflict gradually expanded world war Britain combating France, Spain, Netherlands. Fighting also broke India British East India Company French allied Kingdom Mysore.",
#   'instance': 'dbo:MilitaryConflict'},
#  {'_id': 'Austrian German',
#   'abstract': 'Austrian German (German: Österreichisches Deutsch), Austrian Standard German, Standard Austrian German (German: Österreichisches Standarddeutsch) Austrian High German (German: Österreichisches Hochdeutsch), variety Standard German written spoken Austria North Italy. It highest sociolinguistic prestige locally, variation used media formal situations. In less formal situations, Austrians tend use forms closer identical Bavarian Alemannic dialects, traditionally spoken – rarely written – Austria.',
#   'instance': 'dbo:Language'},
#  {'_id': 'Axiom of choice',
#   'abstract': 'In mathematics, axiom choice, AC, axiom set theory equivalent statement Cartesian product collection non-empty sets non-empty. It states every indexed family nonempty sets exists indexed family elements every . The axiom choice formulated 1904 Ernst Zermelo order formalize proof well-ordering theorem.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Alberta',
#   'abstract': "Alberta (/ælˈbɜːrtə/) western province Canada. With estimated population 4,196,457 July 1, 2015, Canada's fourth-most populous province populous Canada's three prairie provinces. Its area 660,000 square kilometres (250,000 sq mi). Alberta neighbour Saskatchewan districts Northwest Territories established provinces September 1, 1905. The premier Rachel Notley since May 2015.",
#   'instance': 'owl:Thing'},
#  {'_id': 'Angola',
#   'abstract': 'Angola /æŋˈɡoʊlə/, officially Republic Angola (Portuguese: República de Angola pronounced: [ɐ̃ˈɡɔlɐ]; Kikongo, Kimbundu Umbundu: Repubilika ya Ngola), country Southern Africa. It seventh-largest country Africa, bordered Namibia south, Democratic Republic Congo north east, Zambia east, Atlantic Ocean west. The exclave province Cabinda borders Republic Congo Democratic Republic Congo. The capital largest city Angola Luanda.',
#   'instance': 'dbo:Country'},
#  {'_id': 'Mouthwash',
#   'abstract': 'Mouthwash, mouth rinse, oral rinse mouth bath, liquid held mouth passively swilled around mouth contraction perioral muscles and/or movement head, may gargled, head tilted back liquid bubbled back mouth.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Aquarius (constellation)',
#   'abstract': 'Aquarius constellation zodiac, situated Capricornus Pisces. Its name Latin \\',
#   'instance': 'dbo:Constellation'},
#  {'_id': 'A Clockwork Orange (novel)',
#   'abstract': 'A Clockwork Orange dystopian novel Anthony Burgess published 1962. Set near future English society featuring subculture extreme youth violence, teenage protagonist, Alex, narrates violent exploits experiences state authorities intent reforming him. The book partially written Russian-influenced argot called \\',
#   'instance': 'dbo:Book'},
#  {'_id': 'Aries (constellation)',
#   'abstract': "Aries one constellations zodiac. It located northern celestial hemisphere Pisces west Taurus east. The name Aries Latin ram, symbol (Unicode ♈), representing ram's horns. It one 48 constellations described 2nd century astronomer Ptolemy, remains one 88 modern constellations. It mid-sized constellation, ranking 39th overall size, area 441 square degrees (1.1% celestial sphere).",
#   'instance': 'dbo:Constellation'},
#  {'_id': 'Anime',
#   'abstract': 'Anime (Japanese: アニメ, [anime] ) Japanese hand-drawn computer animation. The word abbreviated pronunciation \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Altaic languages',
#   'abstract': 'Altaic (/ælˈteɪᵻk/) proposed language family central Eurasia, widely seen discredited. Various versions included Turkic, Mongolic, Tungusic, Koreanic, Japonic languages. These languages spoken wide arc stretching northeast Asia Central Asia Anatolia eastern Europe. The group named Altai Mountains, mountain range Central Asia.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Aegean Sea',
#   'abstract': 'The Aegean Sea (/ᵻˈdʒiːən/; Greek: Αιγαίο Πέλαγος [eˈʝeo ˈpelaɣos] ; Turkish: Ege Denizi Turkish pronunciation: [eɟe denizi]) elongated embayment Mediterranean Sea located Greek Anatolian peninsulas, i.e., mainlands Greece Turkey. In north, connected Marmara Sea Black Sea Dardanelles Bosphorus. The Aegean Islands within sea bound southern periphery, including Crete Rhodes.',
#   'instance': 'dbo:Sea'},
#  {'_id': 'Aircraft',
#   'abstract': 'An aircraft machine able fly gaining support air. It counters force gravity using either static lift using dynamic lift airfoil, cases downward thrust jet engines. The human activity surrounds aircraft called aviation. Crewed aircraft flown onboard pilot, unmanned aerial vehicles may remotely controlled self-controlled onboard computers. Aircraft may classified different criteria, lift type, aircraft propulsion, usage others.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Asteroid',
#   'abstract': 'Asteroids minor planets, especially inner Solar System. The larger ones also called planetoids. These terms historically applied astronomical object orbiting Sun show disc planet observed characteristics active comet. As minor planets outer Solar System discovered found volatile-based surfaces resemble comets, often distinguished asteroids asteroid belt. In article, term \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Abortion',
#   'abstract': 'Abortion ending pregnancy removing fetus embryo survive outside uterus. An abortion occurs spontaneously also known miscarriage. An abortion may caused purposely called , less frequently, \\',
#   'instance': 'dbo:Disease'},
#  {'_id': 'Aztlan Underground',
#   'abstract': "Aztlan Underground fusion band Los Angeles. Since early 1989, Aztlan Underground played Rapcore. Indigenous drums, flutes, rattles commonplace musical compositions. This unique sound backdrop band's message dignity indigenous people, humanity, Earth. Aztlan Underground cultivating grass roots audience across country, become large loyal underground following. Their music includes spoken word pieces elements punk, hip hop, rock, funk, jazz, indigenous music, among others.",
#   'instance': 'dbo:Band'},
#  {'_id': 'Alfred Hitchcock',
#   'abstract': 'Sir Alfred Joseph Hitchcock, KBE, (13 August 1899 – 29 April 1980) English film director producer, times referred \\',
#   'instance': 'dbo:Person'},
#  {'_id': 'Albert Einstein',
#   'abstract': "Albert Einstein (/ˈaɪnstaɪn/; German: [ˈalbɛɐ̯t ˈaɪnʃtaɪn] ; 14 March 1879 – 18 April 1955) German-born theoretical physicist. He developed general theory relativity, one two pillars modern physics (alongside quantum mechanics). Einstein's work also known influence philosophy science. Einstein best known popular culture mass–energy equivalence formula E = mc2 (which dubbed \\",
#   'instance': 'dbo:Scientist'},
#  {'_id': 'Alfred Nobel',
#   'abstract': '(Not confused Alfred Noble.) Alfred Bernhard Nobel (/noʊˈbɛl/; Swedish: [ˈalfrɛd nʊˈbɛl] ; 21 October 1833 – 10 December 1896) Swedish chemist, engineer, inventor, businessman, philanthropist.',
#   'instance': 'dbo:Person'},
#  {'_id': 'Afghanistan',
#   'abstract': 'Afghanistan /æfˈɡænᵻstæn/ (Pashto/Dari: افغانستان, Afġānistān), officially Islamic Republic Afghanistan, landlocked country located within South Asia Central Asia. It population approximately 32 million, making 42nd populous country world. It bordered Pakistan south east; Iran west; Turkmenistan, Uzbekistan, Tajikistan north; China far northeast. Its territory covers 652,000 km2 (252,000 sq mi), making 41st largest country world.',
#   'instance': 'dbo:Country'},
#  {'_id': 'Albania',
#   'abstract': '(This article modern state. For uses, see Albania (disambiguation).) Albania (/ælˈbeɪniə, ɔːl-/, a(w)l-BAY-nee-ə; Albanian: Shqipëri/Shqipëria; Gheg Albanian: Shqipni/Shqipnia, Shqypni/Shqypnia), officially Republic Albania (Albanian: Republika e Shqipërisë, pronounced [ɾɛpuˈblika ɛ ʃcipəˈɾiːsə]), country Southeast Europe, bordered Montenegro northwest, Kosovo northeast, Republic Macedonia east, Greece south southeast. It coast Adriatic Sea west Ionian Sea southwest. It less 72 km (45 mi) Italy, across Strait Otranto connects Adriatic Sea Ionian Sea.',
#   'instance': 'dbo:Country'},
#  {'_id': 'Attila',
#   'abstract': 'Attila (/ˈætᵻlə/ /əˈtɪlə/; fl. circa 406–453), frequently referred Attila Hun, ruler Huns 434 death March 453. Attila leader Hunnic Empire, tribal confederation consisting Huns, Ostrogoths, Alans among others, territory Central Eastern Europe.',
#   'instance': 'dbo:Royalty'},
#  {'_id': 'Alp Arslan',
#   'abstract': 'Alp Arslan (Honorific Turkish meaning \\',
#   'instance': 'dbo:Royalty'},
#  {'_id': 'Azerbaijan',
#   'abstract': 'Azerbaijan (/ˌæzərbaɪˈdʒɑːn/ AZ-ər-by-JAHN; Azerbaijani: Azərbaycan, Азәрбајҹан, آذربایجان), officially Republic Azerbaijan (Azerbaijani: Azərbaycan Respublikası, Азәрбајҹан Республикасы, رئسپوبلیکاسی آذربایجان), country Transcaucasian region, situated crossroads Southwest Asia Southeastern Europe. It bounded Caspian Sea east, Russia north, Georgia northwest, Armenia west Iran south. The exclave Nakhchivan bounded Armenia north east, Iran south west, short border Turkey north west.',
#   'instance': 'dbo:Country'},
#  {'_id': 'American Film Institute',
#   'abstract': 'The American Film Institute (AFI) film organization educates filmmakers honors heritage moving picture arts U.S. AFI supported private funding public membership.',
#   'instance': 'dbo:Organisation'},
#  {'_id': 'Aberdeenshire',
#   'abstract': 'Aberdeenshire (Scottish Gaelic: Siorrachd Obar Dheathain) one 32 council areas Scotland. It takes name old County Aberdeen substantially different boundaries. Modern Aberdeenshire includes Kincardineshire, well part Banffshire. The old boundaries still officially used purposes, namely land registration lieutenancy.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Analog Brothers',
#   'abstract': 'Analog Brothers experimental hip-hop crew featuring Ice Oscillator also known Ice-T (keyboards, drums, vocals), Keith Korg also known Kool Keith (bass, strings, vocals), Mark Moog also known Marc Live (drums, violyns vocals), Silver Synth also known Black Silver (synthesizer, lazar bell vocals), Rex Roland also known Pimp Rex (keyboards, vocals, production). Its album Pimp Eat featured guest appearances various members Rhyme Syndicate, Odd Oberheim, Jacky jasper (who appears Jacky Jasper song \\',
#   'instance': 'dbo:Band'},
#  {'_id': 'Motor neuron disease',
#   'abstract': 'A motor neuron disease (MND) several neurological disorders selectively affect motor neurons, cells control voluntary muscles body. They include amyotrophic lateral sclerosis (ALS), primary lateral sclerosis (PLS), progressive muscular atrophy (PMA), progressive bulbar palsy (PBP) pseudobulbar palsy; spinal muscular atrophies also sometimes included group. They neurodegenerative nature cause increasing disability eventually, death.',
#   'instance': 'dbo:Disease'},
#  {'_id': 'Ankara',
#   'abstract': "Ankara (English /ˈæŋkərə/; Turkish [ˈaŋ.ka.ɾa] ), formerly known Ancyra Angora, capital Republic Turkey. With population 4,587,558 urban center (2014) 5,150,072 province (2015), Turkey's second largest city Istanbul.",
#   'instance': 'dbo:City'},
#  {'_id': 'Abugida',
#   'abstract': "An abugida /ˌɑːbuːˈɡiːdə/ (from Ge'ez አቡጊዳ ’äbugida), alphasyllabary, segmental writing system consonant–vowel sequences written unit: unit based consonant letter, vowel notation secondary. This contrasts full alphabet, vowels status equal consonants, abjad, vowel marking absent optional. (In less formal contexts, three types script may termed alphabets.) The terms also contrast syllabary, symbols cannot split separate consonants vowels. Abugidas include extensive Brahmic family scripts South Southeast Asia.",
#   'instance': 'owl:Thing'},
#  {'_id': 'Alfons Maria Jakob',
#   'abstract': 'Alfons Maria Jakob (2 July 1884 Aschaffenburg/Bavaria – 17 October 1931 Hamburg) German neurologist worked field neuropathology. He born Aschaffenburg, Bavaria educated medicine universities Munich, Berlin, Strasbourg, received doctorate 1908. During following year, began clinical work psychiatrist Emil Kraepelin laboratory work Franz Nissl Alois Alzheimer Munich.',
#   'instance': 'dbo:Scientist'},
#  {'_id': 'Audi',
#   'abstract': 'Audi AG (pronounced [ˈʔaʊ̯dɪ ʔaːˈgeː] ) German automobile manufacturer designs, engineers, produces, markets distributes luxury vehicles. Audi oversees worldwide operations headquarters Ingolstadt, Bavaria, Germany. Audi-branded vehicles produced nine production facilities worldwide.',
#   'instance': 'dbo:Company'},
#  {'_id': 'Abjad',
#   'abstract': 'An abjad (pronounced /ˈæbdʒɑːd/ /ˈæbdʒæd/) type writing system symbol stands consonant, leaving reader supply appropriate vowel. The name abjad suggested Peter T. Daniels replace common terms \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'MessagePad',
#   'abstract': "The MessagePad first series personal digital assistant devices developed Apple Computer Newton platform 1993. Some electronic engineering manufacture Apple's MessagePad devices undertaken Japan Sharp Corporation. The devices based ARM 610 RISC processor featured handwriting recognition software developed marketed Apple. The devices ran Newton OS.",
#   'instance': 'dbo:InformationAppliance'},
#  {'_id': 'Ancient Egypt',
#   'abstract': 'Ancient Egypt civilization ancient Northeastern Africa, concentrated along lower reaches Nile River modern country Egypt. It one six civilizations arise independently. Egyptian civilization followed prehistoric Egypt coalesced around 3150 BC (according conventional Egyptian chronology) political unification Upper Lower Egypt first pharaoh Narmer (commonly referred Menes). The history ancient Egypt occurred series stable Kingdoms, separated periods relative instability known Intermediate Periods: Old Kingdom Early Bronze Age, Middle Kingdom Middle Bronze Age New Kingdom Late Bronze Age.',
#   'instance': 'owl:Thing'},
#  {'_id': 'A. E. van Vogt',
#   'abstract': 'Alfred Elton van Vogt (/væn voʊt/; April 26, 1912 – January 26, 2000) Canadian-born science fiction author regarded one popular, influential, complex science fiction writers mid-twentieth century: Golden Age genre.',
#   'instance': 'dbo:Writer'},
#  {'_id': 'Arabic',
#   'abstract': 'Arabic (Arabic: العَرَبِيَّة\u200e\u200e, Al-ʻarabiyyah [ʔalʕaraˈbijːah] Arabic: عَرَبِيّ\u200e\u200e ʻarabiyy [ʕaraˈbijː] ) Classical Arabic language 6th century modern descendants, excluding Maltese. Arabic spoken wide arc stretching across Western Asia, North Africa, Horn Africa. Arabic belongs Semitic branch Afroasiatic family.',
#   'instance': 'dbo:Language'},
#  {'_id': 'Alexander the Great',
#   'abstract': "Alexander III Macedon (20/21 July 356 BC – 10/11 June 323 BC), commonly known Alexander Great (Greek: Ἀλέξανδρος ὁ Μέγας, Aléxandros ho Mégas Koine Greek: [a.lék.san.dros ho mé.gas] ), king (basileus) Ancient Greek kingdom Macedon member Argead dynasty. Born Pella 356 BC, Alexander succeeded father, Philip II, throne age twenty. He spent ruling years unprecedented military campaign Asia northeast Africa, age thirty created one largest empires ancient world, stretching Greece northwestern India. He undefeated battle widely considered one history's successful military commanders.",
#   'instance': 'dbo:Royalty'},
#  {'_id': 'Alexander Graham Bell',
#   'abstract': "Alexander Graham Bell (March 3, 1847 – August 2, 1922) Scottish-born scientist, inventor, engineer innovator credited patenting first practical telephone. Bell's father, grandfather, brother associated work elocution speech, mother wife deaf, profoundly influencing Bell's life's work. His research hearing speech led experiment hearing devices eventually culminated Bell awarded first U.S. patent telephone 1876. Bell considered famous invention intrusion real work scientist refused telephone study.",
#   'instance': 'dbo:Person'},
#  {'_id': 'ABBA',
#   'abstract': 'ABBA (stylised ᗅᗺᗷᗅ; Swedish pronunciation: [²abːa]) Swedish pop group formed Stockholm 1972 members Agnetha Fältskog, Björn Ulvaeus, Benny Andersson, Anni-Frid Lyngstad. They became one commercially successful acts history popular music, topping charts worldwide 1974 1982. ABBA Eurovision Song Contest 1974 The Dome Brighton, UK, giving Sweden first triumph contest, successful group ever take part competition.',
#   'instance': 'dbo:Band'},
#  {'_id': 'American Civil War',
#   'abstract': 'The American Civil War civil war United States fought 1861 1865. The Union faced secessionists eleven Southern states grouped together Confederate States America. The Union war, remains bloodiest U.S. history.',
#   'instance': 'dbo:MilitaryConflict'},
#  {'_id': 'Anna Kournikova',
#   'abstract': '(This name uses Eastern Slavic naming customs; patronymic Sergeyevna family name Kournikova.) Anna Sergeyevna Kournikova (Russian: А́нна Серге́евна Ку́рникова; IPA: [ˈannə sʲɪrˈɡʲejɪvnə ˈkurnʲɪkəvə] ; born 7 June 1981) Russian former professional tennis player. Her appearance celebrity status made one best known tennis stars worldwide. At peak fame, fans looking images Kournikova made name one common search strings Google Search.',
#   'instance': 'dbo:TennisPlayer'},
#  {'_id': 'Agnosticism',
#   'abstract': 'Agnosticism view truth values certain claims – especially metaphysical religious claims, whether God, divine, supernatural exist – unknown perhaps unknowable. According philosopher William L. Rowe, \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Arable land',
#   'abstract': 'Arable land (from Latin arabilis, \\',
# ...
#   'instance': 'dbo:Person'},
#  {'_id': 'Arithmetic function',
#   'abstract': 'In number theory, arithmetic, arithmetical, number-theoretic function real complex valued function f(n) defined set natural numbers (i.e., positive integers) \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Alien and Sedition Acts',
#   'abstract': 'The Alien Sedition Acts four bills passed Federalist-dominated 5th United States Congress signed law President John Adams 1798. They made harder immigrant become citizen (Naturalization Act), allowed president imprison deport non-citizens deemed dangerous (Alien Friends Act) hostile nation (Alien Enemies Act), criminalized making false statements critical federal government (Sedition Act).',
#   'instance': 'owl:Thing'},
#  {'_id': 'Achduart',
#   'abstract': 'Achduart (Gaelic: Achadh Dhubhaird) small hamlet Coigach, Wester Ross northwestern Scotland, within Highland council area. It situated 4 km southeast village Achiltibuie, end minor road. A footpath continues hamlet Culnacraig, along coast past Ben More Coigach Strathcanaird. Achduart accommodation facilities tourists, come proximity ocean well seclusion remoteness. There Scottish Youth Hostels Association hostel Acheninver, short distance north.',
#   'instance': 'dbo:Settlement'},
#  {'_id': 'A. E. Housman',
#   'abstract': 'Alfred Edward Housman (/ˈhaʊsmən/; 26 March 1859 – 30 April 1936), usually known A. E. Housman, English classical scholar poet, best known general public cycle poems A Shropshire Lad. Lyrical almost epigrammatic form, poems wistfully evoke dooms disappointments youth English countryside. Their beauty, simplicity distinctive imagery appealed strongly late Victorian Edwardian taste, many early 20th-century English composers First World War. Through song-settings, poems became closely associated era, Shropshire itself.',
#   'instance': 'dbo:Writer'},
#  {'_id': 'AIM-120 AMRAAM',
#   'abstract': 'The AIM-120 Advanced Medium-Range Air-to-Air Missile, AMRAAM (pronounced \\',
#   'instance': 'dbo:Weapon'},
#  {'_id': 'Alexandria',
#   'abstract': "Alexandria (/ˌælɪɡˈzændrɪə/ /ˌælɪɡˈzɑːndrɪə/; Arabic: الإسكندرية al-Iskandariyyah; Egyptian Arabic: اسكندرية\u200e\u200e Eskendereyyah; Coptic: Ⲁⲗⲉⲝⲁⲛⲇⲣⲓⲁ, Ⲣⲁⲕⲟⲧⲉ Alexandria, Rakotə) second largest city major economic centre Egypt, extending 32 km (20 mi) along coast Mediterranean Sea north central part country. Its low elevation Nile delta makes highly vulnerable rising sea levels. Alexandria Egypt's largest seaport, serving approximately 80% Egypt's imports exports. It important industrial center natural gas oil pipelines Suez. Alexandria also important tourist destination.",
#   'instance': 'dbo:Settlement'},
#  {'_id': 'Achiltibuie',
#   'abstract': 'Achiltibuie (/ˌæxᵻltᵻˈbuːi/; Scottish Gaelic: Achd Ille Bhuidhe Field yellow-haired boy) long linear village Ross Cromarty, Highland, Coigach coast northwestern Scotland, overlooking Badentarbet Bay west. Loch Broom Summer Isles lie south. Located 10 miles (16 km) northwest Ullapool crow flies. Achiltibuie central community series townships communities stretching Culnacraig, Badenscallie Polglass (where community hall, primary school Piping School located), Polbain, Reiff Achnahaird.',
#   'instance': 'dbo:Settlement'},
#  {'_id': 'Adin Steinsaltz',
#   'abstract': 'Rabbi Adin Steinsaltz (Hebrew: עדין שטיינזלץ) Adin Even Yisrael (Hebrew: עדין אבן ישראל) (born 1937) teacher, philosopher, social critic, spiritual mentor, hailed Time magazine \\',
#   'instance': 'dbo:Person'},
#  {'_id': 'AGM-65 Maverick',
#   'abstract': "The AGM-65 Maverick air-to-ground tactical missile (AGM) designed close air support. It widely produced precision-guided missile Western world, effective wide range tactical targets, including armor, air defenses, ships, ground transportation fuel storage facilities. The Maverick shares configuration Hughes's AIM-4 Falcon AIM-54 Phoenix, measures 2.4 (8 ft) length 30 cm (12 in) diameter.",
#   'instance': 'dbo:Weapon'},
#  {'_id': 'Mexican tetra',
#   'abstract': 'The Mexican tetra blind cave fish (Astyanax mexicanus) freshwater fishof family Characidae order Characiformes. The type species genus, native Nearctic ecozone, originating lower Rio Grande Neueces Pecos Rivers Texas, well central eastern parts Mexico. This fish, especially blind variant, reasonably popular among aquarists. The Mexican tetra treated subspecies A. fasciatus, widely accepted.',
#   'instance': 'dbo:Fish'},
#  {'_id': 'Lockheed AC-130',
#   'abstract': 'The Lockheed AC-130 gunship heavily armed, long-endurance ground-attack variant C-130 Hercules transport fixed-wing aircraft. It carries wide array anti-ground oriented weapons integrated sophisticated sensors, navigation, fire-control systems. Unlike military fixed-wing aircraft, AC-130 relies visual targeting. Because large profile low operating altitudes (around 7,000 ft) make easy target, usually flies close air support missions night.',
#   'instance': 'dbo:Aircraft'},
#  {'_id': 'Ahmed al-Nami',
#   'abstract': 'Ahmed bin Abdullah al-Nami (Arabic: أحمد بن عبد الله النعمي, Aḥmad bin ‘Abdullāh an-Nāmī; also transliterated Alnami; August 17, 1977 – September 11, 2001) one four hijackers United Airlines Flight 93 part September 11 attacks. Born Saudi Arabia, Nami served muezzin college student. He left family 2000 complete Hajj, later went Afghanistan bound al-Qaeda training camp befriended future hijackers would soon chosen participate attacks.',
#   'instance': 'dbo:Person'},
#  {'_id': 'Archbishopric of Riga',
#   'abstract': 'The Archbishopric Riga (Latin: Archiepiscopatus Rigensis, Low German: Erzbisdom Riga) archbishopric Medieval Livonia, subject Holy See. It established 1186 bishopric Livonia Üxküll, moving Riga became bishopric Riga 1202 elevated archbishopric 1255.',
#   'instance': 'dbo:Country'},
#  {'_id': 'RUR-5 ASROC',
#   'abstract': 'The RUR-5 ASROC (for Anti-Submarine ROCket) all-weather, sea-conditions anti-submarine missile system. Developed United States Navy 1950s, deployed 1960s, updated 1990s, eventually installed 200 USN surface ships, specifically cruisers, destroyers, frigates. The ASROC deployed scores warships many navies, including Canada, Germany, Italy, Japan, Republic China, Greece, Pakistan others.',
#   'instance': 'dbo:Weapon'},
#  {'_id': 'Army of Darkness',
#   'abstract': 'Army Darkness (also known Bruce Campbell vs. Army Darkness) 1992 American horror comedy film directed co-written Sam Raimi, co-produced Robert Tapert Bruce Campbell co-written Ivan Raimi. It stars Campbell Embeth Davidtz. It third installment Evil Dead franchise, continuing Evil Dead II, Ash Williams (Campbell) trapped Middle Ages battles undead quest return present.',
#   'instance': 'dbo:Film'},
#  {'_id': 'Ahmed al-Haznawi',
#   'abstract': 'Ahmed Ibrahim al-Haznawi (Arabic: احمد ابراهيم الحزناوي الغامدي\u200e\u200e, Aḥmad Ibrāhīm al-Ḥaznāwī) (October 11, 1980 – September 11, 2001) one four hijackers United Airlines Flight 93 part September 11 attacks. On September 11, 2001, Haznawi boarded United Airlines Flight 93 assisted hijacking plane, crashed field Shanksville, Pennsylvania, passenger uprising.',
#   'instance': 'dbo:Person'},
#  {'_id': 'ACF Fiorentina',
#   'abstract': 'ACF Fiorentina, commonly referred simply Fiorentina [fjorenˈtiːna], professional Italian football club Florence, Tuscany. Founded merger 1926, refounded 2002 following bankruptcy, Fiorentina played top level Italian football majority existence; four clubs played Serie A seasons.',
#   'instance': 'dbo:SoccerClub'},
#  {'_id': 'Arno',
#   'abstract': 'The Arno river Tuscany region Italy. It important river central Italy Tiber.',
#   'instance': 'dbo:River'},
#  {'_id': 'Albert Frederick, Duke of Prussia',
#   'abstract': 'Albert Frederick (German: Albrecht Friedrich, Polish: Albrecht Fryderyk; 7 May 1553, Königsberg – 28 August 1618, Fischhausen, Rybaki) Duke Prussia 1568 death. He son Albert Prussia Anna Marie Brunswick-Lüneburg. He second last Prussian duke Ansbach branch Hohenzollern family.',
#   'instance': 'dbo:Royalty'},
#  {'_id': 'Amblygonite',
#   'abstract': 'Amblygonite fluorophosphate mineral, (Li,Na)AlPO4(F,OH), composed lithium, sodium, aluminium, phosphate, fluoride hydroxide. The mineral occurs pegmatite deposits easily mistaken albite feldspars. Its density, cleavage flame test lithium diagnostic. Amblygonite forms series montebrasite, low fluorine endmember. Geologic occurrence granite pegmatites, high-temperature tin veins, greisens. Amblygonite occurs spodumene, apatite, lepidolite, tourmaline, lithium-bearing minerals pegmatite veins. It contains 10% lithium, utilized source lithium. The chief commercial sources historically deposits California France.',
#   'instance': 'dbo:Mineral'},
#  {'_id': 'Ariane 5',
#   'abstract': "Ariane 5 European heavy lift launch vehicle part Ariane rocket family, expendable launch system used deliver payloads geostationary transfer orbit (GTO) low Earth orbit (LEO). Ariane 5 rockets manufactured authority European Space Agency (ESA) Centre National d'Etudes Spatiales. Airbus Defence Space prime contractor vehicles, leading consortium sub-contractors. Ariane 5 operated marketed Arianespace part Ariane programme. Airbus Defence Space builds rockets Europe Arianespace launches Guiana Space Centre French Guiana.",
#   'instance': 'dbo:Rocket'},
#  {'_id': 'Running amok',
#   'abstract': 'Running amok, sometimes referred simply amok gone amok, also spelled amuk, Malay language, \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Acephali',
#   'abstract': 'In church history, term acephali applied several sects supposedly leader. E. Cobham Brewer wrote, Dictionary Phrase Fable, acephalites, \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'Amicable numbers',
#   'abstract': 'Amicable numbers two different numbers related sum proper divisors equal number. (A proper divisor number positive factor number number itself. For example, proper divisors 6 1, 2, 3.) A pair amicable numbers constitutes aliquot sequence period 2. A related concept perfect number, number equals sum proper divisors, words number forms aliquot sequence period 1. Numbers members aliquot sequence period greater 2 known sociable numbers.',
#   'instance': 'owl:Thing'},
#  {'_id': 'Agar',
#   'abstract': 'Agar (pronounced /ˈeɪɡɑːr/, US /ˈɑːɡər/, \\',
#   'instance': 'owl:Thing'},
#  {'_id': 'National Alliance (Italy)',
#   'abstract': 'National Alliance (Italian: Alleanza Nazionale, AN) conservative political party Italy. It successor post-fascist Italian Social Movement distanced former ideology convention Fiuggi (\\',
#   'instance': 'dbo:PoliticalParty'},
#  {'_id': 'Anthony the Great',
#   'abstract': 'Saint Anthony Antony (Greek: Ἀντώνιος, Antṓnios; Latin: Antonius, Coptic: Ⲁⲃⲃⲁ Ⲁⲛⲧⲱⲛⲓ ; c. 251–356) Christian monk Egypt, revered since death saint. He distinguished saints named Anthony various epithets: Anthony Great, Anthony Egypt, Anthony Abbot, Anthony Desert, Anthony Anchorite, Anthony Thebes. For importance among Desert Fathers later Christian monasticism, also known Father All Monks. His feast day celebrated January 17 among Orthodox Catholic churches Tobi 22 Egyptian calendar used Coptic Church.',
#   'instance': 'dbo:Saint'},
#  {'_id': 'Albert III, Duke of Saxony',
#   'abstract': 'Albert III (German: Albrecht) (27 January 1443 – 12 September 1500) Duke Saxony. He nicknamed Albert Bold Albert Courageous founded Albertine line House Wettin.',
#   'instance': 'dbo:Royalty'},
#  {'_id': 'Athanasius of Alexandria',
#   'abstract': 'Saint Athanasius Alexandria (/ˌæθəˈneɪʃəs/; Greek: Ἀθανάσιος Ἀλεξανδρείας, Athanásios Alexandrías; c. 296–298 – 2 May 373), also called Athanasius Great, Athanasius Confessor or, primarily Coptic Orthodox Church, Athanasius Apostolic, twentieth bishop Alexandria (as Athanasius I). His episcopate lasted 45 years (c. 8 June 328 – 2 May 373), 17 spent five exiles ordered four different Roman emperors. Athanasius Christian theologian, Church Father, chief defender Trinitarianism Arianism, noted Egyptian leader fourth century.',
#   'instance': 'dbo:Saint'},
#  {'_id': 'Attribution of recent climate change',
#   'abstract': "Attribution recent climate change effort scientifically ascertain mechanisms responsible recent climate changes Earth, commonly known 'global warming'. The effort focused changes observed period instrumental temperature record, records reliable; particularly last 50 years, human activity grown fastest observations troposphere become available. The dominant mechanisms (to IPCC attributes climate change) anthropogenic, i.e., result human activity. They are:",
#   'instance': 'owl:Thing'},
#  {'_id': 'Anthony of Saxony',
#   'abstract': 'Anthony (Dresden, 27 December 1755 – Dresden, 6 June 1836), also known German name Anton (full name: Anton Clemens Theodor Maria Joseph Johann Evangelista Johann Nepomuk Franz Xavier Aloys Januar), King Saxony (1827–1836) House Wettin. He became known Anton der Gütige, (en: \\',
#   'instance': 'dbo:Royalty'},
#  {'_id': 'Al Capone',
#   'abstract': 'Alphonse Gabriel \\',
#   'instance': 'dbo:Criminal'},
#  {'_id': 'Acid rain',
#   'abstract': 'Acid rain rain form precipitation unusually acidic, meaning possesses elevated levels hydrogen ions (low pH). It harmful effects plants, aquatic animals infrastructure. Acid rain caused emissions sulfur dioxide nitrogen oxide, react water molecules atmosphere produce acids. Some governments made efforts since 1970s reduce release sulfur dioxide nitrogen oxide atmosphere positive results. Nitrogen oxides also produced naturally lightning strikes, sulfur dioxide produced volcanic eruptions. The chemicals acid rain cause paint peel, corrosion steel structures bridges, weathering stone buildings statues.',
#   'instance': 'owl:Thing'},
#  {'_id': "Apostles' Creed",
#   'abstract': "The Apostles' Creed (Latin: Symbolum Apostolorum Symbolum Apostolicum), sometimes entitled Symbol Apostles, early statement Christian belief—a creed \\",
#   'instance': 'owl:Thing'},
#  {'_id': 'Arlo Guthrie',
#   'abstract': "Arlo Davy Guthrie (born July 10, 1947) American folk singer-songwriter. Like father, Woody Guthrie, known singing songs protest social injustice. Guthrie's best-known work debut piece, \\",
#   'instance': 'dbo:MusicalArtist'},
#  {'_id': 'Ansbach',
#   'abstract': 'Ansbach (/ˈænzbæk/; German pronunciation: [ˈansbax] ) city German state Bavaria. It capital administrative region Middle Franconia. Ansbach 25 miles (40 km) southwest Nuremberg 90 miles (140 km) north Munich, Fränkische Rezat (Rezat River), tributary Main river. In 2004, population 40,723. The city connections via autobahn A6 highways B13 B14. Ansbach station Nürnberg–Crailsheim Treuchtlingen–Würzburg railways terminus line S4 Nuremberg S-Bahn.',
#   'instance': 'dbo:Town'},
#  {'_id': 'Atlanta',
#   'abstract': 'Atlanta capital populous city U.S. state Georgia, estimated 2015 population 463,878. Atlanta cultural economic center Atlanta metropolitan area, home 5,522,942 people ninth largest metropolitan area United States. Atlanta county seat Fulton County, small portion city extends eastward DeKalb County.',
#   'instance': 'dbo:City'},
#  {'_id': 'Amygdalin',
#   'abstract': 'Amygdalin (from Ancient Greek: ἀμυγδαλή amygdálē \\',
#   'instance': 'dbo:ChemicalCompound'},
#  {'_id': 'Azores',
#   'abstract': 'The Azores (/əˈzɔərz/ ə-ZOHRZ /ˈeɪzɔərz/ AY-zohrz; Portuguese: Açores, [ɐˈsoɾɨʃ]), officially Autonomous Region Azores (Região Autónoma dos Açores), one two autonomous regions Portugal, archipelago composed nine volcanic islands North Atlantic Ocean 1,360 km (850 mi) west continental Portugal, 880 km (550 mi) northwest Madeira, 1,925 km (1,196 mi) southeast Newfoundland, 3,175 km (1,973 mi) Cape Verde, 4,121 km (2,561 mi) east New York City 6,392 km (3,972 mi) northeast Brazil.',
#   'instance': 'dbo:AdministrativeRegion'},
#  {'_id': 'Antioxidant',
#   'abstract': 'An antioxidant molecule inhibits oxidation molecules. Oxidation chemical reaction produce free radicals, leading chain reactions may damage cells. Antioxidants thiols ascorbic acid (vitamin C) terminate chain reactions. The term \\',
#   'instance': 'owl:Thing'}]

# %%
batch_size = 100
doc = list(data.values())
for i in range(0, len(data), batch_size):
    actions = [{
            "_index": INDEX_NAME,
            "_id": x["_id"],
            "_source": {
                "abstract": x["abstract"],
                "instance": x["instance"]
            }
        } for x in doc[i:i+batch_size]]
    helpers.bulk(es, actions, index=INDEX_NAME, raise_on_error=False, raise_on_exception=False)

# %%
search_param={"match": {"instance": "owl:Thing"}}

# %%
response = es.search(index=INDEX_NAME, query=search_param)
print('matching files are\n', response['hits']['total']['value'])
# Out:
# matching files are
#  358

# %%
response['hits']['hits'][0]['_source']['instance']
# Out:
# 'owl:Thing'
